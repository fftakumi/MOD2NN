# %% [markdown]
# # GGG基盤上の薄膜

# %%
#------------------------
# Google Colab上でのみ実行
#------------------------
import time
# %env TOKEN=*************************************
! git clone https://$$TOKEN@github.com/konnitiha3/MOD2NN.git

import sys
sys.path.append('/content/MOD2NN')

from google.colab import drive
drive.mount('/content/drive')

# !pip install GPyOpt
# Out:
# env: TOKEN=*************************************
# Cloning into 'MOD2NN'...
# remote: Enumerating objects: 1025, done.
# remote: Counting objects: 100% (196/196), done.
# remote: Compressing objects: 100% (116/116), done.
# remote: Total 1025 (delta 81), reused 151 (delta 57), pack-reused 829
# Receiving objects: 100% (1025/1025), 36.27 MiB | 27.09 MiB/s, done.
# Resolving deltas: 100% (560/560), done.
# Mounted at /content/drive
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting GPyOpt
#   Downloading GPyOpt-1.2.6.tar.gz (56 kB)
#      |████████████████████████████████| 56 kB 3.5 MB/s
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.7/dist-packages (from GPyOpt) (1.21.6)
# Requirement already satisfied: scipy>=0.16 in /usr/local/lib/python3.7/dist-packages (from GPyOpt) (1.7.3)
# Collecting GPy>=1.8
#   Downloading GPy-1.10.0.tar.gz (959 kB)
#      |████████████████████████████████| 959 kB 15.2 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from GPy>=1.8->GPyOpt) (1.15.0)
# Collecting paramz>=0.9.0
#   Downloading paramz-0.9.5.tar.gz (71 kB)
#      |████████████████████████████████| 71 kB 10.4 MB/s
# Requirement already satisfied: cython>=0.29 in /usr/local/lib/python3.7/dist-packages (from GPy>=1.8->GPyOpt) (0.29.32)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.7/dist-packages (from paramz>=0.9.0->GPy>=1.8->GPyOpt) (4.4.2)
# Building wheels for collected packages: GPyOpt, GPy, paramz
#   Building wheel for GPyOpt (setup.py) ... done
#   Created wheel for GPyOpt: filename=GPyOpt-1.2.6-py3-none-any.whl size=83609 sha256=f06ec1308699ebf744cb142829bcd04d2ed10fc656533325a33443a4c36b7519
#   Stored in directory: /root/.cache/pip/wheels/e6/fa/d1/f9652b5af79f769a0ab74dbead7c7aea9a93c6bc74543fd3ec
#   Building wheel for GPy (setup.py) ... done
#   Created wheel for GPy: filename=GPy-1.10.0-cp37-cp37m-linux_x86_64.whl size=2565101 sha256=839ac837cc967bd38ae60bdf6b78832ee92541ae7b2b9261577fe2ee79cafc2a
#   Stored in directory: /root/.cache/pip/wheels/f7/18/28/dd1ce0192a81b71a3b086fd952511d088b21e8359ea496860a
#   Building wheel for paramz (setup.py) ... done
#   Created wheel for paramz: filename=paramz-0.9.5-py3-none-any.whl size=102566 sha256=5b1e4f1103f5645b552fc838f5179ac2290416acc0a47673386d0bd6d0f41ac2
#   Stored in directory: /root/.cache/pip/wheels/c8/95/f5/ce28482da28162e6028c4b3a32c41d147395825b3cd62bc810
# Successfully built GPyOpt GPy paramz
# Installing collected packages: paramz, GPy, GPyOpt
# Successfully installed GPy-1.10.0 GPyOpt-1.2.6 paramz-0.9.5

# %%
import time
import os
import json
import sys
import re
import glob
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import GPyOpt

from Faraday.two_dim.module.lib.layers import *
from Faraday.two_dim.module.lib import regularizer

tf.random.set_seed(1)

print("TensorFlow:", tf.__version__)
print("Python:", sys.version)

plt.rcParams['font.size'] = 18
# Out:
# TensorFlow: 2.8.2
# Python: 3.7.13 (default, Apr 24 2022, 01:04:09)
# [GCC 7.5.0]

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

y_train = y_train.astype("float32")
y_test = y_test.astype("float32")

# Reserve 10,000 samples for validation
x_val = x_train[-5000:]
y_val = y_train[-5000:]
x_train = x_train[:-5000]
y_train = y_train[:-5000]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# ## MNISTDetector標準モデル
# ShiftL1:L1 = $1.0^{-5}$

# %%
#@title デフォルトのタイトル テキスト
wavelength = 532.0e-9 #@param {type:"number"}
d = 1.0e-6 #@param {type:"number"}
n = 1.5 #@param {type:"number"}

# %%
def create_model(**kwargs):
    shape = (100, 100)
    inputs = tf.keras.Input((28, 28))
    theta = -2.105 * np.pi / 180
    eta = np.arctan(0.9785 * np.pi/180)/2
    l1=1.0e-5
    x = ImageResizing(shape)(inputs)
    x = ImageBinarization(0.5, 0.0, 1.0)(x)
    x = IntensityToElectricField(shape)(x)
    x = MO(shape, limitation='sin', theta=theta, eta=eta, kernel_regularizer=regularizer.ShiftL1Regularizer(l1, np.pi/2))(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=0.5e-3, d=d, n=2.0, method='expand')(x)
    x = MO(shape, limitation='sin', theta=theta, eta=eta, kernel_regularizer=regularizer.ShiftL1Regularizer(l1, np.pi/2))(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=0.5e-3, d=d, n=1.00, method='expand')(x)
    # x = Polarizer(shape)(x)
    #x =ElectricFieldToIntensity(shape)(x)
    #x = MNISTFilter(shape)(x)
    x = FaradayRotationByStokes(shape)(x)
    # x = Argument(shape)(x)
    x = MNISTDetector(10)(x)
    x = tf.keras.layers.Softmax()(x)
    model = tf.keras.Model(inputs, x)
    return model

# %%
model = create_model()
model.summary()
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.sparse_categorical_crossentropy,  # category: sparse_categorical_crossentropy
              metrics=['accuracy'])

epochs = 50
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='accuracy',
    min_delta=0.05,
    patience=2,
)

model_name = "20220809_1"
cholab_path = "/content/drive/MyDrive/D2NN/"
checkpoint_path = cholab_path + "checkpoint/" + model_name + "/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# チェックポイントコールバックを作る
cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

logdir = os.path.join(cholab_path +"logs", model_name)
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

result = model.fit(x_train,
                   y_train,
                   batch_size=64,
                   epochs=epochs,
                   validation_data=(x_val, y_val),
                   callbacks=[cp_callback, tensorboard_callback]
                   )

path = cholab_path + "trained_model/"+ model_name
model.save(path)

df = pd.DataFrame(result.history)
df.to_csv(path + "/history.csv")

with open(path + "/config.json", 'w') as f:
    json.dump(model.get_config(), f, indent=4)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28)]          0
#
#  image_resizing (ImageResizi  (None, 100, 100)         0
#  ng)
#
#  image_binarization (ImageBi  (None, 100, 100)         0
#  narization)
#
#  intensity_to_electric_field  (None, 2, 100, 100)      0
#   (IntensityToElectricField)
#
#  mo (MO)                     (None, 2, 100, 100)       10000
#
#  angular_spectrum (AngularSp  (None, 2, 100, 100)      0
#  ectrum)
#
#  mo_1 (MO)                   (None, 2, 100, 100)       10000
#
#  angular_spectrum_1 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  faraday_rotation_by_stokes   (None, 100, 100)         0
#  (FaradayRotationByStokes)
#
#  mnist_detector (MNISTDetect  (None, 10)               0
#  or)
#
#  softmax (Softmax)           (None, 10)                0
#
# =================================================================
# Total params: 20,000
# Trainable params: 20,000
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 859/860 [============================>.] - ETA: 0s - loss: 2.2361 - accuracy: 0.3737
# Epoch 1: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0001.ckpt
# 860/860 [==============================] - 21s 17ms/step - loss: 2.2361 - accuracy: 0.3737 - val_loss: 2.0036 - val_accuracy: 0.4616
# Epoch 2/50
# 858/860 [============================>.] - ETA: 0s - loss: 1.9634 - accuracy: 0.4529
# Epoch 2: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0002.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.9631 - accuracy: 0.4530 - val_loss: 1.8455 - val_accuracy: 0.4968
# Epoch 3/50
# 858/860 [============================>.] - ETA: 0s - loss: 1.8565 - accuracy: 0.4816
# Epoch 3: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0003.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.8565 - accuracy: 0.4816 - val_loss: 1.7674 - val_accuracy: 0.5106
# Epoch 4/50
# 858/860 [============================>.] - ETA: 0s - loss: 1.7952 - accuracy: 0.4954
# Epoch 4: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0004.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.7951 - accuracy: 0.4955 - val_loss: 1.7138 - val_accuracy: 0.5252
# Epoch 5/50
# 860/860 [==============================] - ETA: 0s - loss: 1.7520 - accuracy: 0.5061
# Epoch 5: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0005.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.7520 - accuracy: 0.5061 - val_loss: 1.6780 - val_accuracy: 0.5326
# Epoch 6/50
# 857/860 [============================>.] - ETA: 0s - loss: 1.7185 - accuracy: 0.5132
# Epoch 6: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0006.ckpt
# 860/860 [==============================] - 15s 17ms/step - loss: 1.7189 - accuracy: 0.5130 - val_loss: 1.6503 - val_accuracy: 0.5384
# Epoch 7/50
# 858/860 [============================>.] - ETA: 0s - loss: 1.6917 - accuracy: 0.5191
# Epoch 7: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0007.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.6917 - accuracy: 0.5191 - val_loss: 1.6262 - val_accuracy: 0.5448
# Epoch 8/50
# 860/860 [==============================] - ETA: 0s - loss: 1.6696 - accuracy: 0.5241
# Epoch 8: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0008.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.6696 - accuracy: 0.5241 - val_loss: 1.6086 - val_accuracy: 0.5456
# Epoch 9/50
# 860/860 [==============================] - ETA: 0s - loss: 1.6509 - accuracy: 0.5274
# Epoch 9: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0009.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.6509 - accuracy: 0.5274 - val_loss: 1.5909 - val_accuracy: 0.5500
# Epoch 10/50
# 857/860 [============================>.] - ETA: 0s - loss: 1.6348 - accuracy: 0.5305
# Epoch 10: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0010.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.6345 - accuracy: 0.5305 - val_loss: 1.5763 - val_accuracy: 0.5532
# Epoch 11/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.6198 - accuracy: 0.5328
# Epoch 11: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0011.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.6198 - accuracy: 0.5329 - val_loss: 1.5626 - val_accuracy: 0.5552
# Epoch 12/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.6077 - accuracy: 0.5350
# Epoch 12: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0012.ckpt
# 860/860 [==============================] - 14s 17ms/step - loss: 1.6078 - accuracy: 0.5349 - val_loss: 1.5516 - val_accuracy: 0.5570
# Epoch 13/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.5969 - accuracy: 0.5364
# Epoch 13: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0013.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.5969 - accuracy: 0.5364 - val_loss: 1.5392 - val_accuracy: 0.5582
# Epoch 14/50
# 860/860 [==============================] - ETA: 0s - loss: 1.5868 - accuracy: 0.5389
# Epoch 14: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0014.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.5868 - accuracy: 0.5389 - val_loss: 1.5333 - val_accuracy: 0.5564
# Epoch 15/50
# 858/860 [============================>.] - ETA: 0s - loss: 1.5779 - accuracy: 0.5394
# Epoch 15: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0015.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.5779 - accuracy: 0.5393 - val_loss: 1.5244 - val_accuracy: 0.5572
# Epoch 16/50
# 860/860 [==============================] - ETA: 0s - loss: 1.5701 - accuracy: 0.5413
# Epoch 16: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0016.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.5701 - accuracy: 0.5413 - val_loss: 1.5166 - val_accuracy: 0.5594
# Epoch 17/50
# 857/860 [============================>.] - ETA: 0s - loss: 1.5627 - accuracy: 0.5424
# Epoch 17: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0017.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.5631 - accuracy: 0.5423 - val_loss: 1.5097 - val_accuracy: 0.5604
# Epoch 18/50
# 858/860 [============================>.] - ETA: 0s - loss: 1.5566 - accuracy: 0.5429
# Epoch 18: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0018.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.5567 - accuracy: 0.5428 - val_loss: 1.5041 - val_accuracy: 0.5620
# Epoch 19/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.5513 - accuracy: 0.5435
# Epoch 19: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0019.ckpt
# 860/860 [==============================] - 15s 17ms/step - loss: 1.5512 - accuracy: 0.5437 - val_loss: 1.4998 - val_accuracy: 0.5602
# Epoch 20/50
# 860/860 [==============================] - ETA: 0s - loss: 1.5460 - accuracy: 0.5459
# Epoch 20: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0020.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.5460 - accuracy: 0.5459 - val_loss: 1.4933 - val_accuracy: 0.5640
# Epoch 21/50
# 857/860 [============================>.] - ETA: 0s - loss: 1.5421 - accuracy: 0.5450
# Epoch 21: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0021.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.5416 - accuracy: 0.5452 - val_loss: 1.4903 - val_accuracy: 0.5630
# Epoch 22/50
# 860/860 [==============================] - ETA: 0s - loss: 1.5380 - accuracy: 0.5458
# Epoch 22: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0022.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.5380 - accuracy: 0.5458 - val_loss: 1.4893 - val_accuracy: 0.5638
# Epoch 23/50
# 858/860 [============================>.] - ETA: 0s - loss: 1.5338 - accuracy: 0.5460
# Epoch 23: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0023.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.5339 - accuracy: 0.5461 - val_loss: 1.4856 - val_accuracy: 0.5666
# Epoch 24/50
# 858/860 [============================>.] - ETA: 0s - loss: 1.5299 - accuracy: 0.5474
# Epoch 24: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0024.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.5299 - accuracy: 0.5473 - val_loss: 1.4811 - val_accuracy: 0.5660
# Epoch 25/50
# 857/860 [============================>.] - ETA: 0s - loss: 1.5260 - accuracy: 0.5474
# Epoch 25: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0025.ckpt
# 860/860 [==============================] - 15s 17ms/step - loss: 1.5265 - accuracy: 0.5472 - val_loss: 1.4789 - val_accuracy: 0.5654
# Epoch 26/50
# 858/860 [============================>.] - ETA: 0s - loss: 1.5235 - accuracy: 0.5476
# Epoch 26: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0026.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.5233 - accuracy: 0.5476 - val_loss: 1.4762 - val_accuracy: 0.5662
# Epoch 27/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.5198 - accuracy: 0.5484
# Epoch 27: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0027.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.5198 - accuracy: 0.5484 - val_loss: 1.4725 - val_accuracy: 0.5650
# Epoch 28/50
# 858/860 [============================>.] - ETA: 0s - loss: 1.5170 - accuracy: 0.5489
# Epoch 28: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0028.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.5172 - accuracy: 0.5487 - val_loss: 1.4696 - val_accuracy: 0.5662
# Epoch 29/50
# 860/860 [==============================] - ETA: 0s - loss: 1.5141 - accuracy: 0.5497
# Epoch 29: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0029.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.5141 - accuracy: 0.5497 - val_loss: 1.4687 - val_accuracy: 0.5656
# Epoch 30/50
# 860/860 [==============================] - ETA: 0s - loss: 1.5117 - accuracy: 0.5488
# Epoch 30: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0030.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.5117 - accuracy: 0.5488 - val_loss: 1.4639 - val_accuracy: 0.5684
# Epoch 31/50
# 857/860 [============================>.] - ETA: 0s - loss: 1.5088 - accuracy: 0.5484
# Epoch 31: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0031.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.5090 - accuracy: 0.5483 - val_loss: 1.4650 - val_accuracy: 0.5660
# Epoch 32/50
# 858/860 [============================>.] - ETA: 0s - loss: 1.5070 - accuracy: 0.5499
# Epoch 32: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0032.ckpt
# 860/860 [==============================] - 15s 17ms/step - loss: 1.5069 - accuracy: 0.5499 - val_loss: 1.4598 - val_accuracy: 0.5660
# Epoch 33/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.5040 - accuracy: 0.5510
# Epoch 33: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0033.ckpt
# 860/860 [==============================] - 14s 16ms/step - loss: 1.5041 - accuracy: 0.5510 - val_loss: 1.4596 - val_accuracy: 0.5678
# Epoch 34/50
# 857/860 [============================>.] - ETA: 0s - loss: 1.5020 - accuracy: 0.5504
# Epoch 34: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0034.ckpt
# 860/860 [==============================] - 14s 17ms/step - loss: 1.5022 - accuracy: 0.5503 - val_loss: 1.4575 - val_accuracy: 0.5658
# Epoch 35/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.4997 - accuracy: 0.5513
# Epoch 35: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0035.ckpt
# 860/860 [==============================] - 14s 17ms/step - loss: 1.4998 - accuracy: 0.5513 - val_loss: 1.4557 - val_accuracy: 0.5660
# Epoch 36/50
# 860/860 [==============================] - ETA: 0s - loss: 1.4979 - accuracy: 0.5506
# Epoch 36: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0036.ckpt
# 860/860 [==============================] - 14s 17ms/step - loss: 1.4979 - accuracy: 0.5506 - val_loss: 1.4526 - val_accuracy: 0.5678
# Epoch 37/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.4961 - accuracy: 0.5505
# Epoch 37: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0037.ckpt
# 860/860 [==============================] - 14s 17ms/step - loss: 1.4961 - accuracy: 0.5505 - val_loss: 1.4520 - val_accuracy: 0.5668
# Epoch 38/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.4942 - accuracy: 0.5515
# Epoch 38: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0038.ckpt
# 860/860 [==============================] - 15s 18ms/step - loss: 1.4942 - accuracy: 0.5515 - val_loss: 1.4499 - val_accuracy: 0.5674
# Epoch 39/50
# 858/860 [============================>.] - ETA: 0s - loss: 1.4927 - accuracy: 0.5514
# Epoch 39: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0039.ckpt
# 860/860 [==============================] - 15s 17ms/step - loss: 1.4924 - accuracy: 0.5515 - val_loss: 1.4472 - val_accuracy: 0.5674
# Epoch 40/50
# 858/860 [============================>.] - ETA: 0s - loss: 1.4906 - accuracy: 0.5516
# Epoch 40: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0040.ckpt
# 860/860 [==============================] - 15s 17ms/step - loss: 1.4908 - accuracy: 0.5515 - val_loss: 1.4458 - val_accuracy: 0.5696
# Epoch 41/50
# 860/860 [==============================] - ETA: 0s - loss: 1.4891 - accuracy: 0.5515
# Epoch 41: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0041.ckpt
# 860/860 [==============================] - 14s 17ms/step - loss: 1.4891 - accuracy: 0.5515 - val_loss: 1.4454 - val_accuracy: 0.5678
# Epoch 42/50
# 858/860 [============================>.] - ETA: 0s - loss: 1.4873 - accuracy: 0.5519
# Epoch 42: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0042.ckpt
# 860/860 [==============================] - 15s 17ms/step - loss: 1.4871 - accuracy: 0.5519 - val_loss: 1.4439 - val_accuracy: 0.5696
# Epoch 43/50
# 860/860 [==============================] - ETA: 0s - loss: 1.4856 - accuracy: 0.5520
# Epoch 43: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0043.ckpt
# 860/860 [==============================] - 14s 17ms/step - loss: 1.4856 - accuracy: 0.5520 - val_loss: 1.4403 - val_accuracy: 0.5702
# Epoch 44/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.4840 - accuracy: 0.5520
# Epoch 44: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0044.ckpt
# 860/860 [==============================] - 15s 17ms/step - loss: 1.4840 - accuracy: 0.5520 - val_loss: 1.4412 - val_accuracy: 0.5678
# Epoch 45/50
# 857/860 [============================>.] - ETA: 0s - loss: 1.4825 - accuracy: 0.5521
# Epoch 45: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0045.ckpt
# 860/860 [==============================] - 15s 17ms/step - loss: 1.4825 - accuracy: 0.5522 - val_loss: 1.4382 - val_accuracy: 0.5720
# Epoch 46/50
# 857/860 [============================>.] - ETA: 0s - loss: 1.4814 - accuracy: 0.5522
# Epoch 46: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0046.ckpt
# 860/860 [==============================] - 15s 17ms/step - loss: 1.4815 - accuracy: 0.5523 - val_loss: 1.4373 - val_accuracy: 0.5694
# Epoch 47/50
# 857/860 [============================>.] - ETA: 0s - loss: 1.4797 - accuracy: 0.5525
# Epoch 47: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0047.ckpt
# 860/860 [==============================] - 15s 17ms/step - loss: 1.4798 - accuracy: 0.5526 - val_loss: 1.4380 - val_accuracy: 0.5680
# Epoch 48/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.4787 - accuracy: 0.5529
# Epoch 48: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0048.ckpt
# 860/860 [==============================] - 15s 17ms/step - loss: 1.4786 - accuracy: 0.5529 - val_loss: 1.4351 - val_accuracy: 0.5684
# Epoch 49/50
# 860/860 [==============================] - ETA: 0s - loss: 1.4772 - accuracy: 0.5528
# Epoch 49: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0049.ckpt
# 860/860 [==============================] - 15s 17ms/step - loss: 1.4772 - accuracy: 0.5528 - val_loss: 1.4354 - val_accuracy: 0.5702
# Epoch 50/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.4761 - accuracy: 0.5531
# Epoch 50: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_1/cp-0050.ckpt
# 860/860 [==============================] - 15s 17ms/step - loss: 1.4763 - accuracy: 0.5531 - val_loss: 1.4334 - val_accuracy: 0.5704
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/D2NN/trained_model/20220809_1/assets

# %% [markdown]
# ## 検出距離最適化最適化 (BO)
# 2値化後のloss最小化最小化

# %%
def create_model(**kwargs):
    shape = (100, 100)
    inputs = tf.keras.Input((28, 28))
    theta = -2.105 * np.pi / 180
    eta = np.arctan(0.9785 * np.pi/180)/2
    l1=1.0e-5
    z = kwargs["z"]
    x = ImageResizing(shape)(inputs)
    x = ImageBinarization(0.5, 0.0, 1.0)(x)
    x = IntensityToElectricField(shape)(x)
    x = MO(shape, limitation='sin', theta=theta, eta=eta, kernel_regularizer=regularizer.ShiftL1Regularizer(l1, np.pi/2))(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=0.5e-3, d=d, n=2.0, method='expand')(x)
    x = MO(shape, limitation='sin', theta=theta, eta=eta, kernel_regularizer=regularizer.ShiftL1Regularizer(l1, np.pi/2))(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=z, d=d, n=1.00, method='expand')(x)
    # x = Polarizer(shape)(x)
    #x =ElectricFieldToIntensity(shape)(x)
    #x = MNISTFilter(shape)(x)
    x = FaradayRotationByStokes(shape)(x)
    # x = Argument(shape)(x)
    x = MNISTDetector(10)(x)
    x = tf.keras.layers.Softmax()(x)
    model = tf.keras.Model(inputs, x)
    return model

# %%
history = []
count = 0
def train(**kwargs):
    global count
    count += 1
    model = create_model(**kwargs)
    model.summary()
    model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss=tf.keras.losses.sparse_categorical_crossentropy,  # category: sparse_categorical_crossentropy
                  metrics=['accuracy'])

    epochs = 50
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='accuracy',
        min_delta=0.05,
        patience=2,
    )

    model_name = "20220809_BO/" + str(count)
    cholab_path = "/content/drive/MyDrive/D2NN/"
    checkpoint_path = cholab_path + "checkpoint/" + model_name + "/cp-{epoch:04d}.ckpt"
    checkpoint_dir = os.path.dirname(checkpoint_path)

    # チェックポイントコールバックを作る
    cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                     save_weights_only=True,
                                                     verbose=1)

    logdir = os.path.join(cholab_path +"logs", model_name)
    tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

    result = model.fit(x_train,
                       y_train,
                       batch_size=64,
                       epochs=epochs,
                       validation_data=(x_val, y_val),
                       callbacks=[cp_callback, tensorboard_callback]
                       )

    path = cholab_path + "trained_model/"+ model_name
    model.save(path)

    df = pd.DataFrame(result.history)
    df.to_csv(path + "/history.csv")

    with open(path + "/config.json", 'w') as f:
        json.dump(model.get_config(), f, indent=4)

    bi_model = tf.keras.models.load_model(path)
    pattern = r'mo'
    mo_layers = []
    for layer in bi_model.layers:
        result = re.match(pattern, layer.name)
        if result:
            mo_layers.append(layer)

    for layer in mo_layers:
        w = layer.get_weights()
        bi_w = np.where(w[0]>0, np.pi/2, -np.pi/2)
        w[0] = bi_w
        layer.set_weights(w)
    evaluate = bi_model.evaluate(x_test, y_test)
    history.append([count, *kwargs.values(), evaluate[0], evaluate[1]])
    df = pd.DataFrame(history)
    df.to_csv("/content/drive/MyDrive/D2NN/trained_model/20220809_BO/bo_history.csv")

    return evaluate

# %%
bounds = [{'name': 'z',  'type': 'continuous',  'domain': (0.1e-3, 5.0e-3)}]
# ベイズ最適化する関数（上記で書いたブラックボックス）を定義します。
# xが入力で、出力はreturnされます。
def f(x):
    print(x)
    evaluation = train(
        z = float(x[:,0]))
    print("loss:{0} \t\t accuracy:{1}".format(evaluation[0], evaluation[1]))
    print(evaluation)
    return evaluation[0]

# 事前探索を行います。
opt_mnist = GPyOpt.methods.BayesianOptimization(f=f, domain=bounds)

# 最適なパラメータを探索します。
opt_mnist.run_optimization(max_iter=50)
print("optimized parameters: {0}".format(opt_mnist.x_opt))
print("optimized loss: {0}".format(opt_mnist.fx_opt))
# Out:
# [[0.00267388]]
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28)]          0
#
#  image_resizing_1 (ImageResi  (None, 100, 100)         0
#  zing)
#
#  image_binarization_1 (Image  (None, 100, 100)         0
#  Binarization)
#
#  intensity_to_electric_field  (None, 2, 100, 100)      0
#  _1 (IntensityToElectricFiel
#  d)
#
#  mo_2 (MO)                   (None, 2, 100, 100)       10000
#
#  angular_spectrum_2 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  mo_3 (MO)                   (None, 2, 100, 100)       10000
#
#  angular_spectrum_3 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  faraday_rotation_by_stokes_  (None, 100, 100)         0
#  1 (FaradayRotationByStokes)
#
#  mnist_detector_1 (MNISTDete  (None, 10)               0
#  ctor)
#
#  softmax_1 (Softmax)         (None, 10)                0
#
# =================================================================
# Total params: 20,000
# Trainable params: 20,000
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 859/860 [============================>.] - ETA: 0s - loss: 2.2729 - accuracy: 0.3326
# Epoch 1: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_BO/1/cp-0001.ckpt
# 860/860 [==============================] - 17s 17ms/step - loss: 2.2728 - accuracy: 0.3326 - val_loss: 2.0904 - val_accuracy: 0.4258
# Epoch 2/50
# 859/860 [============================>.] - ETA: 0s - loss: 2.0594 - accuracy: 0.4328
# Epoch 2: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_BO/1/cp-0002.ckpt
# 860/860 [==============================] - 14s 17ms/step - loss: 2.0593 - accuracy: 0.4329 - val_loss: 1.9687 - val_accuracy: 0.4710
# Epoch 3/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.9749 - accuracy: 0.4623
# Epoch 3: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_BO/1/cp-0003.ckpt
# 860/860 [==============================] - 15s 17ms/step - loss: 1.9749 - accuracy: 0.4623 - val_loss: 1.9098 - val_accuracy: 0.4840
# Epoch 4/50
# 857/860 [============================>.] - ETA: 0s - loss: 1.9253 - accuracy: 0.4755
# Epoch 4: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_BO/1/cp-0004.ckpt
# 860/860 [==============================] - 15s 17ms/step - loss: 1.9253 - accuracy: 0.4755 - val_loss: 1.8675 - val_accuracy: 0.4954
# Epoch 5/50
# 857/860 [============================>.] - ETA: 0s - loss: 1.8887 - accuracy: 0.4840
# Epoch 5: saving model to /content/drive/MyDrive/D2NN/checkpoint/20220809_BO/1/cp-0005.ckpt
# 860/860 [==============================] - 14s 17ms/step - loss: 1.8889 - accuracy: 0.4839 - val_loss: 1.8355 - val_accuracy: 0.5008
# Epoch 6/50
# 106/860 [==>...........................] - ETA: 11s - loss: 1.8725 - accuracy: 0.4861
