# %%
import sys
sys.path.append('/notebooks/MOD2NN')

# %%
import os
import json

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

from CNN.module.lib.layers import *
from Faraday.two_dim.module.lib.layers import *

from Faraday.two_dim import matplotlib_style
matplotlib_style.paper()

tf.random.set_seed(1)

print("TensorFlow:", tf.__version__)
print("Python:", sys.version)

plt.rcParams['font.size'] = 18
# Out:
# TensorFlow: 2.9.1
# Python: 3.9.13 (main, May 23 2022, 22:01:06)
# [GCC 9.4.0]
# TensorFlow: 2.9.1
# Python: 3.9.13 (main, May 23 2022, 22:01:06)
# [GCC 9.4.0]

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = np.sqrt(x_train.astype("float32") / 255.0)
x_test = np.sqrt(x_test.astype("float32") / 255.0)

y_train = y_train.astype("float32")
y_test = y_test.astype("float32")

# Reserve 10,000 samples for validation
x_val = x_train[-5000:]
y_val = y_train[-5000:]
x_train = x_train[:-5000]
y_train = y_train[:-5000]

# %%
#@title デフォルトのタイトル テキスト
wavelength = 633.0e-9 #@param {type:"number"}
d = 1.0e-6 #@param {type:"number"}
n = 1.5 #@param {type:"number"}
z = 0.7e-3 #@param {type:"number"}

# %%
def create_model(**kwargs):
    shape = (100, 100)
    theta = kwargs["theta"]
    eta = 0.
    tf.random.set_seed(kwargs["seed"])
    inputs = tf.keras.Input((28, 28))
    x = ImageResizing(shape)(inputs)
    x = IntensityToElectricField(shape)(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=z, d=d, n=n, method='expand')(x)
    x = MO(shape, limitation='sin', theta=theta, eta=eta)(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=z, d=d, n=n, method='expand')(x)
    x = MO(shape, limitation='sin', theta=theta, eta=eta)(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=z, d=d, n=n, method='expand')(x)
    x = MO(shape, limitation='sin', theta=theta, eta=eta)(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=z, d=d, n=n, method='expand')(x)
    x = MO(shape, limitation='sin', theta=theta, eta=eta)(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=z, d=d, n=n, method='expand')(x)
    x = MO(shape, limitation='sin', theta=theta, eta=eta)(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=z, d=d, n=n, method='expand')(x)
    x = Polarizer(shape, trainable=True)(x)
    x = ElectricFieldToIntensity(shape)(x)
    x = MNISTDetector(shape)(x)
    x = tf.keras.layers.Softmax()(x)
    model = tf.keras.Model(inputs, x)
    return model

# %%
def train(seed, theta, num):
    model_name = "20230110/intens/" + str(num)
    checkpoint_path = "checkpoint/" + model_name + "/cp-{epoch:04d}.ckpt"
    checkpoint_dir = os.path.dirname(checkpoint_path)
    path = "trained_model/"+ model_name

    model = create_model(seed=seed, theta=theta)
    model.summary()
    model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss=tf.keras.losses.sparse_categorical_crossentropy,  # category: sparse_categorical_crossentropy
                  metrics=["accuracy"]
                  )

    epochs = 50
    early_stopping = tf.keras.callbacks.EarlyStopping(
            monitor='loss',
            min_delta=0.0002,
            patience=2,
        )


    # チェックポイントコールバックを作る
    cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                     save_weights_only=True,
                                                     verbose=1)

    logdir = os.path.join("logs", model_name)
    tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

    result = model.fit(x_train,
                       y_train,
                       batch_size=64,
                       epochs=epochs,
                       validation_data=(x_val, y_val),
                       callbacks=[cp_callback, tensorboard_callback]
                       )

    model.save(path)

    df = pd.DataFrame(result.history)
    df.to_csv(path + "/history.csv")



    with open(path + "/config.json", 'w') as f:
        json.dump(model.get_config(), f, indent=4)

# %% [markdown]
# # 検光子無し

# %%
theta = [np.pi, np.pi/2., np.pi/5., np.pi/10., np.pi/100]
for i, _theta in enumerate(theta):
    train(seed=1, theta=_theta, num=i)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28)]          0
#
#  image_resizing (ImageResizi  (None, 100, 100)         0
#  ng)
#
#  intensity_to_electric_field  (None, 2, 100, 100)      0
#   (IntensityToElectricField)
#
#  angular_spectrum (AngularSp  (None, 2, 100, 100)      0
#  ectrum)
#
#  mo (MO)                     (None, 2, 100, 100)       10000
#
#  angular_spectrum_1 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  mo_1 (MO)                   (None, 2, 100, 100)       10000
#
#  angular_spectrum_2 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  mo_2 (MO)                   (None, 2, 100, 100)       10000
#
#  angular_spectrum_3 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  mo_3 (MO)                   (None, 2, 100, 100)       10000
#
#  angular_spectrum_4 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  mo_4 (MO)                   (None, 2, 100, 100)       10000
#
#  angular_spectrum_5 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  electric_field_to_intensity  (None, 100, 100)         0
#   (ElectricFieldToIntensity)
#
#  mnist_detector (MNISTDetect  (None, 10)               0
#  or)
#
#  softmax (Softmax)           (None, 10)                0
#
# =================================================================
# Total params: 50,000
# Trainable params: 50,000
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 859/860 [============================>.] - ETA: 0s - loss: 2.0748 - accuracy: 0.6504
# Epoch 1: saving model to checkpoint/20230110/intens/0/cp-0001.ckpt
# 860/860 [==============================] - 48s 51ms/step - loss: 2.0743 - accuracy: 0.6505 - val_loss: 0.3326 - val_accuracy: 0.9078
# Epoch 2/50
# 860/860 [==============================] - ETA: 0s - loss: 0.3461 - accuracy: 0.9023
# Epoch 2: saving model to checkpoint/20230110/intens/0/cp-0002.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.3461 - accuracy: 0.9023 - val_loss: 0.2161 - val_accuracy: 0.9418
# Epoch 3/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.2596 - accuracy: 0.9276
# Epoch 3: saving model to checkpoint/20230110/intens/0/cp-0003.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.2595 - accuracy: 0.9275 - val_loss: 0.1807 - val_accuracy: 0.9528
# Epoch 4/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.2201 - accuracy: 0.9381
# Epoch 4: saving model to checkpoint/20230110/intens/0/cp-0004.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.2200 - accuracy: 0.9381 - val_loss: 0.1549 - val_accuracy: 0.9562
# Epoch 5/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1951 - accuracy: 0.9447
# Epoch 5: saving model to checkpoint/20230110/intens/0/cp-0005.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1950 - accuracy: 0.9447 - val_loss: 0.1417 - val_accuracy: 0.9598
# Epoch 6/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1771 - accuracy: 0.9500
# Epoch 6: saving model to checkpoint/20230110/intens/0/cp-0006.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1771 - accuracy: 0.9500 - val_loss: 0.1349 - val_accuracy: 0.9632
# Epoch 7/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1636 - accuracy: 0.9531
# Epoch 7: saving model to checkpoint/20230110/intens/0/cp-0007.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1635 - accuracy: 0.9531 - val_loss: 0.1347 - val_accuracy: 0.9640
# Epoch 8/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1538 - accuracy: 0.9550
# Epoch 8: saving model to checkpoint/20230110/intens/0/cp-0008.ckpt
# 860/860 [==============================] - 43s 51ms/step - loss: 0.1538 - accuracy: 0.9550 - val_loss: 0.1210 - val_accuracy: 0.9674
# Epoch 9/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1460 - accuracy: 0.9583
# Epoch 9: saving model to checkpoint/20230110/intens/0/cp-0009.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1460 - accuracy: 0.9583 - val_loss: 0.1160 - val_accuracy: 0.9672
# Epoch 10/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1383 - accuracy: 0.9605
# Epoch 10: saving model to checkpoint/20230110/intens/0/cp-0010.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1383 - accuracy: 0.9605 - val_loss: 0.1190 - val_accuracy: 0.9654
# Epoch 11/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1339 - accuracy: 0.9615
# Epoch 11: saving model to checkpoint/20230110/intens/0/cp-0011.ckpt
# 860/860 [==============================] - 43s 51ms/step - loss: 0.1339 - accuracy: 0.9615 - val_loss: 0.1153 - val_accuracy: 0.9670
# Epoch 12/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1290 - accuracy: 0.9626
# Epoch 12: saving model to checkpoint/20230110/intens/0/cp-0012.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1292 - accuracy: 0.9626 - val_loss: 0.1084 - val_accuracy: 0.9684
# Epoch 13/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1251 - accuracy: 0.9642
# Epoch 13: saving model to checkpoint/20230110/intens/0/cp-0013.ckpt
# 860/860 [==============================] - 43s 49ms/step - loss: 0.1251 - accuracy: 0.9642 - val_loss: 0.1093 - val_accuracy: 0.9704
# Epoch 14/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1217 - accuracy: 0.9647
# Epoch 14: saving model to checkpoint/20230110/intens/0/cp-0014.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1217 - accuracy: 0.9647 - val_loss: 0.1058 - val_accuracy: 0.9714
# Epoch 15/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1188 - accuracy: 0.9659
# Epoch 15: saving model to checkpoint/20230110/intens/0/cp-0015.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1188 - accuracy: 0.9659 - val_loss: 0.1080 - val_accuracy: 0.9692
# Epoch 16/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1164 - accuracy: 0.9663
# Epoch 16: saving model to checkpoint/20230110/intens/0/cp-0016.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1164 - accuracy: 0.9663 - val_loss: 0.1009 - val_accuracy: 0.9726
# Epoch 17/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1144 - accuracy: 0.9670
# Epoch 17: saving model to checkpoint/20230110/intens/0/cp-0017.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 0.1145 - accuracy: 0.9670 - val_loss: 0.1009 - val_accuracy: 0.9712
# Epoch 18/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1117 - accuracy: 0.9680
# Epoch 18: saving model to checkpoint/20230110/intens/0/cp-0018.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1117 - accuracy: 0.9680 - val_loss: 0.0961 - val_accuracy: 0.9736
# Epoch 19/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1093 - accuracy: 0.9686
# Epoch 19: saving model to checkpoint/20230110/intens/0/cp-0019.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1093 - accuracy: 0.9687 - val_loss: 0.0998 - val_accuracy: 0.9728
# Epoch 20/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1087 - accuracy: 0.9687
# Epoch 20: saving model to checkpoint/20230110/intens/0/cp-0020.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1087 - accuracy: 0.9687 - val_loss: 0.1052 - val_accuracy: 0.9704
# Epoch 21/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1064 - accuracy: 0.9694
# Epoch 21: saving model to checkpoint/20230110/intens/0/cp-0021.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 0.1063 - accuracy: 0.9694 - val_loss: 0.0952 - val_accuracy: 0.9724
# Epoch 22/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1054 - accuracy: 0.9693
# Epoch 22: saving model to checkpoint/20230110/intens/0/cp-0022.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 0.1054 - accuracy: 0.9693 - val_loss: 0.1075 - val_accuracy: 0.9692
# Epoch 23/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1033 - accuracy: 0.9704
# Epoch 23: saving model to checkpoint/20230110/intens/0/cp-0023.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 0.1033 - accuracy: 0.9704 - val_loss: 0.0946 - val_accuracy: 0.9740
# Epoch 24/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1027 - accuracy: 0.9704
# Epoch 24: saving model to checkpoint/20230110/intens/0/cp-0024.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1027 - accuracy: 0.9703 - val_loss: 0.0963 - val_accuracy: 0.9714
# Epoch 25/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1007 - accuracy: 0.9709
# Epoch 25: saving model to checkpoint/20230110/intens/0/cp-0025.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1007 - accuracy: 0.9709 - val_loss: 0.0985 - val_accuracy: 0.9700
# Epoch 26/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1008 - accuracy: 0.9710
# Epoch 26: saving model to checkpoint/20230110/intens/0/cp-0026.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1008 - accuracy: 0.9711 - val_loss: 0.0939 - val_accuracy: 0.9732
# Epoch 27/50
# 860/860 [==============================] - ETA: 0s - loss: 0.0995 - accuracy: 0.9711
# Epoch 27: saving model to checkpoint/20230110/intens/0/cp-0027.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.0995 - accuracy: 0.9711 - val_loss: 0.0916 - val_accuracy: 0.9722
# Epoch 28/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.0981 - accuracy: 0.9718
# Epoch 28: saving model to checkpoint/20230110/intens/0/cp-0028.ckpt
# 860/860 [==============================] - 43s 49ms/step - loss: 0.0980 - accuracy: 0.9718 - val_loss: 0.0928 - val_accuracy: 0.9742
# Epoch 29/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.0970 - accuracy: 0.9721
# Epoch 29: saving model to checkpoint/20230110/intens/0/cp-0029.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.0970 - accuracy: 0.9721 - val_loss: 0.0945 - val_accuracy: 0.9716
# Epoch 30/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.0969 - accuracy: 0.9722
# Epoch 30: saving model to checkpoint/20230110/intens/0/cp-0030.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 0.0969 - accuracy: 0.9722 - val_loss: 0.0906 - val_accuracy: 0.9734
# Epoch 31/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.0955 - accuracy: 0.9724
# Epoch 31: saving model to checkpoint/20230110/intens/0/cp-0031.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.0955 - accuracy: 0.9724 - val_loss: 0.0917 - val_accuracy: 0.9744
# Epoch 32/50
# 860/860 [==============================] - ETA: 0s - loss: 0.0946 - accuracy: 0.9725
# Epoch 32: saving model to checkpoint/20230110/intens/0/cp-0032.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.0946 - accuracy: 0.9725 - val_loss: 0.0903 - val_accuracy: 0.9732
# Epoch 33/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.0936 - accuracy: 0.9725
# Epoch 33: saving model to checkpoint/20230110/intens/0/cp-0033.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.0937 - accuracy: 0.9725 - val_loss: 0.0915 - val_accuracy: 0.9746
# Epoch 34/50
# 860/860 [==============================] - ETA: 0s - loss: 0.0936 - accuracy: 0.9729
# Epoch 34: saving model to checkpoint/20230110/intens/0/cp-0034.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.0936 - accuracy: 0.9729 - val_loss: 0.0944 - val_accuracy: 0.9738
# Epoch 35/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.0923 - accuracy: 0.9735
# Epoch 35: saving model to checkpoint/20230110/intens/0/cp-0035.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.0923 - accuracy: 0.9735 - val_loss: 0.0876 - val_accuracy: 0.9758
# Epoch 36/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.0924 - accuracy: 0.9737
# Epoch 36: saving model to checkpoint/20230110/intens/0/cp-0036.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.0924 - accuracy: 0.9737 - val_loss: 0.0873 - val_accuracy: 0.9760
# Epoch 37/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.0912 - accuracy: 0.9740
# Epoch 37: saving model to checkpoint/20230110/intens/0/cp-0037.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.0911 - accuracy: 0.9740 - val_loss: 0.0889 - val_accuracy: 0.9736
# Epoch 38/50
# 860/860 [==============================] - ETA: 0s - loss: 0.0909 - accuracy: 0.9739
# Epoch 38: saving model to checkpoint/20230110/intens/0/cp-0038.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.0909 - accuracy: 0.9739 - val_loss: 0.0881 - val_accuracy: 0.9744
# Epoch 39/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.0904 - accuracy: 0.9743
# Epoch 39: saving model to checkpoint/20230110/intens/0/cp-0039.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.0903 - accuracy: 0.9743 - val_loss: 0.0900 - val_accuracy: 0.9756
# Epoch 40/50
# 860/860 [==============================] - ETA: 0s - loss: 0.0898 - accuracy: 0.9744
# Epoch 40: saving model to checkpoint/20230110/intens/0/cp-0040.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.0898 - accuracy: 0.9744 - val_loss: 0.0984 - val_accuracy: 0.9704
# Epoch 41/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.0897 - accuracy: 0.9740
# Epoch 41: saving model to checkpoint/20230110/intens/0/cp-0041.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.0896 - accuracy: 0.9740 - val_loss: 0.0882 - val_accuracy: 0.9752
# Epoch 42/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.0882 - accuracy: 0.9743
# Epoch 42: saving model to checkpoint/20230110/intens/0/cp-0042.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.0882 - accuracy: 0.9743 - val_loss: 0.0905 - val_accuracy: 0.9748
# Epoch 43/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.0881 - accuracy: 0.9748
# Epoch 43: saving model to checkpoint/20230110/intens/0/cp-0043.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.0881 - accuracy: 0.9749 - val_loss: 0.0901 - val_accuracy: 0.9758
# Epoch 44/50
# 860/860 [==============================] - ETA: 0s - loss: 0.0886 - accuracy: 0.9741
# Epoch 44: saving model to checkpoint/20230110/intens/0/cp-0044.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.0886 - accuracy: 0.9741 - val_loss: 0.0851 - val_accuracy: 0.9746
# Epoch 45/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.0876 - accuracy: 0.9750
# Epoch 45: saving model to checkpoint/20230110/intens/0/cp-0045.ckpt
# 860/860 [==============================] - 43s 51ms/step - loss: 0.0875 - accuracy: 0.9750 - val_loss: 0.0935 - val_accuracy: 0.9738
# Epoch 46/50
# 860/860 [==============================] - ETA: 0s - loss: 0.0872 - accuracy: 0.9747
# Epoch 46: saving model to checkpoint/20230110/intens/0/cp-0046.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.0872 - accuracy: 0.9747 - val_loss: 0.0880 - val_accuracy: 0.9758
# Epoch 47/50
# 860/860 [==============================] - ETA: 0s - loss: 0.0878 - accuracy: 0.9745
# Epoch 47: saving model to checkpoint/20230110/intens/0/cp-0047.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.0878 - accuracy: 0.9745 - val_loss: 0.0899 - val_accuracy: 0.9752
# Epoch 48/50
# 860/860 [==============================] - ETA: 0s - loss: 0.0860 - accuracy: 0.9755
# Epoch 48: saving model to checkpoint/20230110/intens/0/cp-0048.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.0860 - accuracy: 0.9755 - val_loss: 0.0878 - val_accuracy: 0.9770
# Epoch 49/50
# 860/860 [==============================] - ETA: 0s - loss: 0.0863 - accuracy: 0.9752
# Epoch 49: saving model to checkpoint/20230110/intens/0/cp-0049.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.0863 - accuracy: 0.9752 - val_loss: 0.0870 - val_accuracy: 0.9758
# Epoch 50/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.0860 - accuracy: 0.9746
# Epoch 50: saving model to checkpoint/20230110/intens/0/cp-0050.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.0860 - accuracy: 0.9746 - val_loss: 0.0874 - val_accuracy: 0.9760
# WARNING:absl:Found untraced functions such as get_limited_eta, get_limited_theta, get_limited_eta, get_limited_theta, get_limited_eta while saving (showing 5 of 11). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_model/20230110/intens/0/assets
# INFO:tensorflow:Assets written to: trained_model/20230110/intens/0/assets
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28)]          0
#
#  image_resizing_1 (ImageResi  (None, 100, 100)         0
#  zing)
#
#  intensity_to_electric_field  (None, 2, 100, 100)      0
#  _1 (IntensityToElectricFiel
#  d)
#
#  angular_spectrum_6 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  mo_5 (MO)                   (None, 2, 100, 100)       10000
#
#  angular_spectrum_7 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  mo_6 (MO)                   (None, 2, 100, 100)       10000
#
#  angular_spectrum_8 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  mo_7 (MO)                   (None, 2, 100, 100)       10000
#
#  angular_spectrum_9 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  mo_8 (MO)                   (None, 2, 100, 100)       10000
#
#  angular_spectrum_10 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  mo_9 (MO)                   (None, 2, 100, 100)       10000
#
#  angular_spectrum_11 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  electric_field_to_intensity  (None, 100, 100)         0
#  _1 (ElectricFieldToIntensit
#  y)
#
#  mnist_detector_1 (MNISTDete  (None, 10)               0
#  ctor)
#
#  softmax_1 (Softmax)         (None, 10)                0
#
# =================================================================
# Total params: 50,000
# Trainable params: 50,000
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 860/860 [==============================] - ETA: 0s - loss: 5.3138 - accuracy: 0.4882
# Epoch 1: saving model to checkpoint/20230110/intens/1/cp-0001.ckpt
# 860/860 [==============================] - 46s 51ms/step - loss: 5.3138 - accuracy: 0.4882 - val_loss: 0.5518 - val_accuracy: 0.8400
# Epoch 2/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5194 - accuracy: 0.8518
# Epoch 2: saving model to checkpoint/20230110/intens/1/cp-0002.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 0.5194 - accuracy: 0.8518 - val_loss: 0.3082 - val_accuracy: 0.9134
# Epoch 3/50
# 860/860 [==============================] - ETA: 0s - loss: 0.3612 - accuracy: 0.8987
# Epoch 3: saving model to checkpoint/20230110/intens/1/cp-0003.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 0.3612 - accuracy: 0.8987 - val_loss: 0.2431 - val_accuracy: 0.9342
# Epoch 4/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.2977 - accuracy: 0.9171
# Epoch 4: saving model to checkpoint/20230110/intens/1/cp-0004.ckpt
# 860/860 [==============================] - 50s 58ms/step - loss: 0.2976 - accuracy: 0.9171 - val_loss: 0.2058 - val_accuracy: 0.9442
# Epoch 5/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.2604 - accuracy: 0.9277
# Epoch 5: saving model to checkpoint/20230110/intens/1/cp-0005.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 0.2604 - accuracy: 0.9277 - val_loss: 0.1854 - val_accuracy: 0.9486
# Epoch 6/50
# 860/860 [==============================] - ETA: 0s - loss: 0.2342 - accuracy: 0.9350
# Epoch 6: saving model to checkpoint/20230110/intens/1/cp-0006.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.2342 - accuracy: 0.9350 - val_loss: 0.1738 - val_accuracy: 0.9522
# Epoch 7/50
# 860/860 [==============================] - ETA: 0s - loss: 0.2150 - accuracy: 0.9396
# Epoch 7: saving model to checkpoint/20230110/intens/1/cp-0007.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.2150 - accuracy: 0.9396 - val_loss: 0.1623 - val_accuracy: 0.9572
# Epoch 8/50
# 860/860 [==============================] - ETA: 0s - loss: 0.2005 - accuracy: 0.9439
# Epoch 8: saving model to checkpoint/20230110/intens/1/cp-0008.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.2005 - accuracy: 0.9439 - val_loss: 0.1499 - val_accuracy: 0.9592
# Epoch 9/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1884 - accuracy: 0.9473
# Epoch 9: saving model to checkpoint/20230110/intens/1/cp-0009.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1886 - accuracy: 0.9473 - val_loss: 0.1434 - val_accuracy: 0.9584
# Epoch 10/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1784 - accuracy: 0.9498
# Epoch 10: saving model to checkpoint/20230110/intens/1/cp-0010.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1784 - accuracy: 0.9498 - val_loss: 0.1408 - val_accuracy: 0.9604
# Epoch 11/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1705 - accuracy: 0.9517
# Epoch 11: saving model to checkpoint/20230110/intens/1/cp-0011.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1705 - accuracy: 0.9517 - val_loss: 0.1371 - val_accuracy: 0.9620
# Epoch 12/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1635 - accuracy: 0.9533
# Epoch 12: saving model to checkpoint/20230110/intens/1/cp-0012.ckpt
# 860/860 [==============================] - 52s 61ms/step - loss: 0.1635 - accuracy: 0.9533 - val_loss: 0.1306 - val_accuracy: 0.9624
# Epoch 13/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1575 - accuracy: 0.9554
# Epoch 13: saving model to checkpoint/20230110/intens/1/cp-0013.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1576 - accuracy: 0.9554 - val_loss: 0.1297 - val_accuracy: 0.9636
# Epoch 14/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1525 - accuracy: 0.9569
# Epoch 14: saving model to checkpoint/20230110/intens/1/cp-0014.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1525 - accuracy: 0.9569 - val_loss: 0.1257 - val_accuracy: 0.9652
# Epoch 15/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1479 - accuracy: 0.9572
# Epoch 15: saving model to checkpoint/20230110/intens/1/cp-0015.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1479 - accuracy: 0.9572 - val_loss: 0.1240 - val_accuracy: 0.9658
# Epoch 16/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1440 - accuracy: 0.9587
# Epoch 16: saving model to checkpoint/20230110/intens/1/cp-0016.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1440 - accuracy: 0.9587 - val_loss: 0.1190 - val_accuracy: 0.9674
# Epoch 17/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1411 - accuracy: 0.9596
# Epoch 17: saving model to checkpoint/20230110/intens/1/cp-0017.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1411 - accuracy: 0.9596 - val_loss: 0.1169 - val_accuracy: 0.9682
# Epoch 18/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1375 - accuracy: 0.9606
# Epoch 18: saving model to checkpoint/20230110/intens/1/cp-0018.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1375 - accuracy: 0.9606 - val_loss: 0.1143 - val_accuracy: 0.9674
# Epoch 19/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1347 - accuracy: 0.9622
# Epoch 19: saving model to checkpoint/20230110/intens/1/cp-0019.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1347 - accuracy: 0.9622 - val_loss: 0.1152 - val_accuracy: 0.9686
# Epoch 20/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1327 - accuracy: 0.9616
# Epoch 20: saving model to checkpoint/20230110/intens/1/cp-0020.ckpt
# 860/860 [==============================] - 43s 51ms/step - loss: 0.1327 - accuracy: 0.9616 - val_loss: 0.1184 - val_accuracy: 0.9678
# Epoch 21/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1299 - accuracy: 0.9629
# Epoch 21: saving model to checkpoint/20230110/intens/1/cp-0021.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1299 - accuracy: 0.9629 - val_loss: 0.1104 - val_accuracy: 0.9696
# Epoch 22/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1281 - accuracy: 0.9631
# Epoch 22: saving model to checkpoint/20230110/intens/1/cp-0022.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 0.1281 - accuracy: 0.9631 - val_loss: 0.1177 - val_accuracy: 0.9668
# Epoch 23/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1261 - accuracy: 0.9647
# Epoch 23: saving model to checkpoint/20230110/intens/1/cp-0023.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 0.1261 - accuracy: 0.9647 - val_loss: 0.1089 - val_accuracy: 0.9702
# Epoch 24/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1246 - accuracy: 0.9647
# Epoch 24: saving model to checkpoint/20230110/intens/1/cp-0024.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 0.1246 - accuracy: 0.9647 - val_loss: 0.1096 - val_accuracy: 0.9702
# Epoch 25/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1227 - accuracy: 0.9655
# Epoch 25: saving model to checkpoint/20230110/intens/1/cp-0025.ckpt
# 860/860 [==============================] - 46s 53ms/step - loss: 0.1228 - accuracy: 0.9654 - val_loss: 0.1115 - val_accuracy: 0.9692
# Epoch 26/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1219 - accuracy: 0.9658
# Epoch 26: saving model to checkpoint/20230110/intens/1/cp-0026.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1219 - accuracy: 0.9658 - val_loss: 0.1081 - val_accuracy: 0.9694
# Epoch 27/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1205 - accuracy: 0.9657
# Epoch 27: saving model to checkpoint/20230110/intens/1/cp-0027.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1205 - accuracy: 0.9657 - val_loss: 0.1061 - val_accuracy: 0.9692
# Epoch 28/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1188 - accuracy: 0.9657
# Epoch 28: saving model to checkpoint/20230110/intens/1/cp-0028.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1188 - accuracy: 0.9657 - val_loss: 0.1065 - val_accuracy: 0.9714
# Epoch 29/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1176 - accuracy: 0.9665
# Epoch 29: saving model to checkpoint/20230110/intens/1/cp-0029.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1175 - accuracy: 0.9665 - val_loss: 0.1070 - val_accuracy: 0.9704
# Epoch 30/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1167 - accuracy: 0.9670
# Epoch 30: saving model to checkpoint/20230110/intens/1/cp-0030.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1167 - accuracy: 0.9670 - val_loss: 0.1048 - val_accuracy: 0.9712
# Epoch 31/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1157 - accuracy: 0.9669
# Epoch 31: saving model to checkpoint/20230110/intens/1/cp-0031.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1157 - accuracy: 0.9669 - val_loss: 0.1043 - val_accuracy: 0.9718
# Epoch 32/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1144 - accuracy: 0.9672
# Epoch 32: saving model to checkpoint/20230110/intens/1/cp-0032.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1146 - accuracy: 0.9672 - val_loss: 0.1037 - val_accuracy: 0.9718
# Epoch 33/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1134 - accuracy: 0.9680
# Epoch 33: saving model to checkpoint/20230110/intens/1/cp-0033.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1134 - accuracy: 0.9680 - val_loss: 0.1038 - val_accuracy: 0.9712
# Epoch 34/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1127 - accuracy: 0.9676
# Epoch 34: saving model to checkpoint/20230110/intens/1/cp-0034.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 0.1127 - accuracy: 0.9676 - val_loss: 0.1062 - val_accuracy: 0.9706
# Epoch 35/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1118 - accuracy: 0.9680
# Epoch 35: saving model to checkpoint/20230110/intens/1/cp-0035.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 0.1117 - accuracy: 0.9680 - val_loss: 0.1033 - val_accuracy: 0.9710
# Epoch 36/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1115 - accuracy: 0.9686
# Epoch 36: saving model to checkpoint/20230110/intens/1/cp-0036.ckpt
# 860/860 [==============================] - 45s 52ms/step - loss: 0.1115 - accuracy: 0.9686 - val_loss: 0.1015 - val_accuracy: 0.9718
# Epoch 37/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1104 - accuracy: 0.9683
# Epoch 37: saving model to checkpoint/20230110/intens/1/cp-0037.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1103 - accuracy: 0.9683 - val_loss: 0.1020 - val_accuracy: 0.9728
# Epoch 38/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1100 - accuracy: 0.9684
# Epoch 38: saving model to checkpoint/20230110/intens/1/cp-0038.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1100 - accuracy: 0.9684 - val_loss: 0.1033 - val_accuracy: 0.9708
# Epoch 39/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1092 - accuracy: 0.9690
# Epoch 39: saving model to checkpoint/20230110/intens/1/cp-0039.ckpt
# 860/860 [==============================] - 45s 52ms/step - loss: 0.1092 - accuracy: 0.9690 - val_loss: 0.1024 - val_accuracy: 0.9712
# Epoch 40/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1085 - accuracy: 0.9688
# Epoch 40: saving model to checkpoint/20230110/intens/1/cp-0040.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1085 - accuracy: 0.9688 - val_loss: 0.1075 - val_accuracy: 0.9706
# Epoch 41/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1081 - accuracy: 0.9688
# Epoch 41: saving model to checkpoint/20230110/intens/1/cp-0041.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1081 - accuracy: 0.9689 - val_loss: 0.1025 - val_accuracy: 0.9740
# Epoch 42/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1073 - accuracy: 0.9691
# Epoch 42: saving model to checkpoint/20230110/intens/1/cp-0042.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.1072 - accuracy: 0.9691 - val_loss: 0.1018 - val_accuracy: 0.9722
# Epoch 43/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1066 - accuracy: 0.9695
# Epoch 43: saving model to checkpoint/20230110/intens/1/cp-0043.ckpt
# 860/860 [==============================] - 52s 61ms/step - loss: 0.1066 - accuracy: 0.9695 - val_loss: 0.1025 - val_accuracy: 0.9722
# Epoch 44/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1067 - accuracy: 0.9698
# Epoch 44: saving model to checkpoint/20230110/intens/1/cp-0044.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 0.1067 - accuracy: 0.9698 - val_loss: 0.0988 - val_accuracy: 0.9732
# Epoch 45/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1056 - accuracy: 0.9695
# Epoch 45: saving model to checkpoint/20230110/intens/1/cp-0045.ckpt
# 860/860 [==============================] - 54s 63ms/step - loss: 0.1056 - accuracy: 0.9695 - val_loss: 0.1039 - val_accuracy: 0.9722
# Epoch 46/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1049 - accuracy: 0.9699
# Epoch 46: saving model to checkpoint/20230110/intens/1/cp-0046.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.1049 - accuracy: 0.9699 - val_loss: 0.1018 - val_accuracy: 0.9724
# Epoch 47/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1054 - accuracy: 0.9702
# Epoch 47: saving model to checkpoint/20230110/intens/1/cp-0047.ckpt
# 860/860 [==============================] - 56s 65ms/step - loss: 0.1054 - accuracy: 0.9702 - val_loss: 0.1023 - val_accuracy: 0.9730
# Epoch 48/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1040 - accuracy: 0.9701
# Epoch 48: saving model to checkpoint/20230110/intens/1/cp-0048.ckpt
# 860/860 [==============================] - 50s 59ms/step - loss: 0.1040 - accuracy: 0.9701 - val_loss: 0.1001 - val_accuracy: 0.9740
# Epoch 49/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1041 - accuracy: 0.9703
# Epoch 49: saving model to checkpoint/20230110/intens/1/cp-0049.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.1041 - accuracy: 0.9703 - val_loss: 0.0978 - val_accuracy: 0.9742
# Epoch 50/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1035 - accuracy: 0.9710
# Epoch 50: saving model to checkpoint/20230110/intens/1/cp-0050.ckpt
# 860/860 [==============================] - 47s 55ms/step - loss: 0.1036 - accuracy: 0.9710 - val_loss: 0.0997 - val_accuracy: 0.9732
# WARNING:absl:Found untraced functions such as get_limited_eta, get_limited_theta, get_limited_eta, get_limited_theta, get_limited_eta while saving (showing 5 of 11). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_model/20230110/intens/1/assets
# INFO:tensorflow:Assets written to: trained_model/20230110/intens/1/assets
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 28, 28)]          0
#
#  image_resizing_2 (ImageResi  (None, 100, 100)         0
#  zing)
#
#  intensity_to_electric_field  (None, 2, 100, 100)      0
#  _2 (IntensityToElectricFiel
#  d)
#
#  angular_spectrum_12 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  mo_10 (MO)                  (None, 2, 100, 100)       10000
#
#  angular_spectrum_13 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  mo_11 (MO)                  (None, 2, 100, 100)       10000
#
#  angular_spectrum_14 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  mo_12 (MO)                  (None, 2, 100, 100)       10000
#
#  angular_spectrum_15 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  mo_13 (MO)                  (None, 2, 100, 100)       10000
#
#  angular_spectrum_16 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  mo_14 (MO)                  (None, 2, 100, 100)       10000
#
#  angular_spectrum_17 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  electric_field_to_intensity  (None, 100, 100)         0
#  _2 (ElectricFieldToIntensit
#  y)
#
#  mnist_detector_2 (MNISTDete  (None, 10)               0
#  ctor)
#
#  softmax_2 (Softmax)         (None, 10)                0
#
# =================================================================
# Total params: 50,000
# Trainable params: 50,000
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 859/860 [============================>.] - ETA: 0s - loss: 12.4496 - accuracy: 0.2359
# Epoch 1: saving model to checkpoint/20230110/intens/2/cp-0001.ckpt
# 860/860 [==============================] - 46s 50ms/step - loss: 12.4455 - accuracy: 0.2359 - val_loss: 2.2289 - val_accuracy: 0.5162
# Epoch 2/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.5524 - accuracy: 0.6367
# Epoch 2: saving model to checkpoint/20230110/intens/2/cp-0002.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 1.5524 - accuracy: 0.6368 - val_loss: 0.8538 - val_accuracy: 0.7804
# Epoch 3/50
# 860/860 [==============================] - ETA: 0s - loss: 0.8762 - accuracy: 0.7761
# Epoch 3: saving model to checkpoint/20230110/intens/2/cp-0003.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.8762 - accuracy: 0.7761 - val_loss: 0.5655 - val_accuracy: 0.8508
# Epoch 4/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.6517 - accuracy: 0.8301
# Epoch 4: saving model to checkpoint/20230110/intens/2/cp-0004.ckpt
# 860/860 [==============================] - 52s 61ms/step - loss: 0.6516 - accuracy: 0.8302 - val_loss: 0.4388 - val_accuracy: 0.8816
# Epoch 5/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5328 - accuracy: 0.8586
# Epoch 5: saving model to checkpoint/20230110/intens/2/cp-0005.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.5327 - accuracy: 0.8586 - val_loss: 0.3695 - val_accuracy: 0.8992
# Epoch 6/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4587 - accuracy: 0.8785
# Epoch 6: saving model to checkpoint/20230110/intens/2/cp-0006.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.4586 - accuracy: 0.8785 - val_loss: 0.3269 - val_accuracy: 0.9092
# Epoch 7/50
# 860/860 [==============================] - ETA: 0s - loss: 0.4088 - accuracy: 0.8903
# Epoch 7: saving model to checkpoint/20230110/intens/2/cp-0007.ckpt
# 860/860 [==============================] - 55s 64ms/step - loss: 0.4088 - accuracy: 0.8903 - val_loss: 0.2937 - val_accuracy: 0.9170
# Epoch 8/50
# 860/860 [==============================] - ETA: 0s - loss: 0.3730 - accuracy: 0.8989
# Epoch 8: saving model to checkpoint/20230110/intens/2/cp-0008.ckpt
# 860/860 [==============================] - 47s 55ms/step - loss: 0.3730 - accuracy: 0.8989 - val_loss: 0.2683 - val_accuracy: 0.9240
# Epoch 9/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3455 - accuracy: 0.9052
# Epoch 9: saving model to checkpoint/20230110/intens/2/cp-0009.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.3458 - accuracy: 0.9051 - val_loss: 0.2532 - val_accuracy: 0.9300
# Epoch 10/50
# 860/860 [==============================] - ETA: 0s - loss: 0.3244 - accuracy: 0.9102
# Epoch 10: saving model to checkpoint/20230110/intens/2/cp-0010.ckpt
# 860/860 [==============================] - 52s 61ms/step - loss: 0.3244 - accuracy: 0.9102 - val_loss: 0.2405 - val_accuracy: 0.9314
# Epoch 11/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3075 - accuracy: 0.9147
# Epoch 11: saving model to checkpoint/20230110/intens/2/cp-0011.ckpt
# 860/860 [==============================] - 54s 63ms/step - loss: 0.3075 - accuracy: 0.9147 - val_loss: 0.2313 - val_accuracy: 0.9350
# Epoch 12/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.2933 - accuracy: 0.9177
# Epoch 12: saving model to checkpoint/20230110/intens/2/cp-0012.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 0.2936 - accuracy: 0.9176 - val_loss: 0.2205 - val_accuracy: 0.9372
# Epoch 13/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.2823 - accuracy: 0.9212
# Epoch 13: saving model to checkpoint/20230110/intens/2/cp-0013.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.2822 - accuracy: 0.9212 - val_loss: 0.2140 - val_accuracy: 0.9384
# Epoch 14/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.2727 - accuracy: 0.9239
# Epoch 14: saving model to checkpoint/20230110/intens/2/cp-0014.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.2727 - accuracy: 0.9239 - val_loss: 0.2091 - val_accuracy: 0.9410
# Epoch 15/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.2640 - accuracy: 0.9261
# Epoch 15: saving model to checkpoint/20230110/intens/2/cp-0015.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 0.2641 - accuracy: 0.9261 - val_loss: 0.2038 - val_accuracy: 0.9422
# Epoch 16/50
# 860/860 [==============================] - ETA: 0s - loss: 0.2571 - accuracy: 0.9286
# Epoch 16: saving model to checkpoint/20230110/intens/2/cp-0016.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.2571 - accuracy: 0.9286 - val_loss: 0.1969 - val_accuracy: 0.9464
# Epoch 17/50
# 860/860 [==============================] - ETA: 0s - loss: 0.2511 - accuracy: 0.9301
# Epoch 17: saving model to checkpoint/20230110/intens/2/cp-0017.ckpt
# 860/860 [==============================] - 44s 52ms/step - loss: 0.2511 - accuracy: 0.9301 - val_loss: 0.1947 - val_accuracy: 0.9460
# Epoch 18/50
# 860/860 [==============================] - ETA: 0s - loss: 0.2455 - accuracy: 0.9316
# Epoch 18: saving model to checkpoint/20230110/intens/2/cp-0018.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 0.2455 - accuracy: 0.9316 - val_loss: 0.1898 - val_accuracy: 0.9480
# Epoch 19/50
# 860/860 [==============================] - ETA: 0s - loss: 0.2405 - accuracy: 0.9325
# Epoch 19: saving model to checkpoint/20230110/intens/2/cp-0019.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.2405 - accuracy: 0.9325 - val_loss: 0.1870 - val_accuracy: 0.9500
# Epoch 20/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.2363 - accuracy: 0.9341
# Epoch 20: saving model to checkpoint/20230110/intens/2/cp-0020.ckpt
# 860/860 [==============================] - 61s 71ms/step - loss: 0.2362 - accuracy: 0.9341 - val_loss: 0.1842 - val_accuracy: 0.9490
# Epoch 21/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.2320 - accuracy: 0.9350
# Epoch 21: saving model to checkpoint/20230110/intens/2/cp-0021.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.2319 - accuracy: 0.9350 - val_loss: 0.1815 - val_accuracy: 0.9494
# Epoch 22/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.2286 - accuracy: 0.9369
# Epoch 22: saving model to checkpoint/20230110/intens/2/cp-0022.ckpt
# 860/860 [==============================] - 54s 63ms/step - loss: 0.2285 - accuracy: 0.9369 - val_loss: 0.1792 - val_accuracy: 0.9512
# Epoch 23/50
# 860/860 [==============================] - ETA: 0s - loss: 0.2252 - accuracy: 0.9376
# Epoch 23: saving model to checkpoint/20230110/intens/2/cp-0023.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.2252 - accuracy: 0.9376 - val_loss: 0.1768 - val_accuracy: 0.9516
# Epoch 24/50
# 860/860 [==============================] - ETA: 0s - loss: 0.2218 - accuracy: 0.9383
# Epoch 24: saving model to checkpoint/20230110/intens/2/cp-0024.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.2218 - accuracy: 0.9383 - val_loss: 0.1754 - val_accuracy: 0.9524
# Epoch 25/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.2192 - accuracy: 0.9393
# ...
#
#  mo_16 (MO)                  (None, 2, 100, 100)       10000
#
#  angular_spectrum_20 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  mo_17 (MO)                  (None, 2, 100, 100)       10000
#
#  angular_spectrum_21 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  mo_18 (MO)                  (None, 2, 100, 100)       10000
#
#  angular_spectrum_22 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  mo_19 (MO)                  (None, 2, 100, 100)       10000
#
#  angular_spectrum_23 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  electric_field_to_intensity  (None, 100, 100)         0
#  _3 (ElectricFieldToIntensit
#  y)
#
#  mnist_detector_3 (MNISTDete  (None, 10)               0
#  ctor)
#
#  softmax_3 (Softmax)         (None, 10)                0
#
# =================================================================
# Total params: 50,000
# Trainable params: 50,000
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 859/860 [============================>.] - ETA: 0s - loss: 20.8901 - accuracy: 0.1115
# Epoch 1: saving model to checkpoint/20230110/intens/3/cp-0001.ckpt
# 860/860 [==============================] - 46s 51ms/step - loss: 20.8842 - accuracy: 0.1115 - val_loss: 6.5883 - val_accuracy: 0.2076
# Epoch 2/50
# 860/860 [==============================] - ETA: 0s - loss: 4.8948 - accuracy: 0.2929
# Epoch 2: saving model to checkpoint/20230110/intens/3/cp-0002.ckpt
# 860/860 [==============================] - 52s 61ms/step - loss: 4.8948 - accuracy: 0.2929 - val_loss: 3.3285 - val_accuracy: 0.4044
# Epoch 3/50
# 859/860 [============================>.] - ETA: 0s - loss: 2.9930 - accuracy: 0.4321
# Epoch 3: saving model to checkpoint/20230110/intens/3/cp-0003.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 2.9923 - accuracy: 0.4322 - val_loss: 2.2201 - val_accuracy: 0.5374
# Epoch 4/50
# 859/860 [============================>.] - ETA: 0s - loss: 2.2043 - accuracy: 0.5396
# Epoch 4: saving model to checkpoint/20230110/intens/3/cp-0004.ckpt
# 860/860 [==============================] - 45s 52ms/step - loss: 2.2039 - accuracy: 0.5396 - val_loss: 1.6926 - val_accuracy: 0.6230
# Epoch 5/50
# 860/860 [==============================] - ETA: 0s - loss: 1.8077 - accuracy: 0.6021
# Epoch 5: saving model to checkpoint/20230110/intens/3/cp-0005.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 1.8077 - accuracy: 0.6021 - val_loss: 1.4150 - val_accuracy: 0.6738
# Epoch 6/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.5815 - accuracy: 0.6422
# Epoch 6: saving model to checkpoint/20230110/intens/3/cp-0006.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 1.5813 - accuracy: 0.6422 - val_loss: 1.2471 - val_accuracy: 0.7038
# Epoch 7/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.4370 - accuracy: 0.6682
# Epoch 7: saving model to checkpoint/20230110/intens/3/cp-0007.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 1.4365 - accuracy: 0.6683 - val_loss: 1.1353 - val_accuracy: 0.7294
# Epoch 8/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.3367 - accuracy: 0.6869
# Epoch 8: saving model to checkpoint/20230110/intens/3/cp-0008.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 1.3365 - accuracy: 0.6869 - val_loss: 1.0573 - val_accuracy: 0.7460
# Epoch 9/50
# 860/860 [==============================] - ETA: 0s - loss: 1.2637 - accuracy: 0.7011
# Epoch 9: saving model to checkpoint/20230110/intens/3/cp-0009.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 1.2637 - accuracy: 0.7011 - val_loss: 1.0004 - val_accuracy: 0.7578
# Epoch 10/50
# 860/860 [==============================] - ETA: 0s - loss: 1.2081 - accuracy: 0.7116
# Epoch 10: saving model to checkpoint/20230110/intens/3/cp-0010.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 1.2081 - accuracy: 0.7116 - val_loss: 0.9577 - val_accuracy: 0.7652
# Epoch 11/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.1644 - accuracy: 0.7199
# Epoch 11: saving model to checkpoint/20230110/intens/3/cp-0011.ckpt
# 860/860 [==============================] - 46s 54ms/step - loss: 1.1644 - accuracy: 0.7199 - val_loss: 0.9226 - val_accuracy: 0.7728
# Epoch 12/50
# 860/860 [==============================] - ETA: 0s - loss: 1.1290 - accuracy: 0.7261
# Epoch 12: saving model to checkpoint/20230110/intens/3/cp-0012.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 1.1290 - accuracy: 0.7261 - val_loss: 0.8936 - val_accuracy: 0.7780
# Epoch 13/50
# 860/860 [==============================] - ETA: 0s - loss: 1.1005 - accuracy: 0.7308
# Epoch 13: saving model to checkpoint/20230110/intens/3/cp-0013.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 1.1005 - accuracy: 0.7308 - val_loss: 0.8714 - val_accuracy: 0.7844
# Epoch 14/50
# 860/860 [==============================] - ETA: 0s - loss: 1.0767 - accuracy: 0.7355
# Epoch 14: saving model to checkpoint/20230110/intens/3/cp-0014.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 1.0767 - accuracy: 0.7355 - val_loss: 0.8516 - val_accuracy: 0.7898
# Epoch 15/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.0566 - accuracy: 0.7389
# Epoch 15: saving model to checkpoint/20230110/intens/3/cp-0015.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 1.0567 - accuracy: 0.7389 - val_loss: 0.8362 - val_accuracy: 0.7926
# Epoch 16/50
# 860/860 [==============================] - ETA: 0s - loss: 1.0397 - accuracy: 0.7419
# Epoch 16: saving model to checkpoint/20230110/intens/3/cp-0016.ckpt
# 860/860 [==============================] - 53s 61ms/step - loss: 1.0397 - accuracy: 0.7419 - val_loss: 0.8210 - val_accuracy: 0.7970
# Epoch 17/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.0254 - accuracy: 0.7455
# Epoch 17: saving model to checkpoint/20230110/intens/3/cp-0017.ckpt
# 860/860 [==============================] - 45s 53ms/step - loss: 1.0252 - accuracy: 0.7455 - val_loss: 0.8113 - val_accuracy: 0.7988
# Epoch 18/50
# 860/860 [==============================] - ETA: 0s - loss: 1.0126 - accuracy: 0.7473
# Epoch 18: saving model to checkpoint/20230110/intens/3/cp-0018.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 1.0126 - accuracy: 0.7473 - val_loss: 0.8007 - val_accuracy: 0.8010
# Epoch 19/50
# 860/860 [==============================] - ETA: 0s - loss: 1.0016 - accuracy: 0.7494
# Epoch 19: saving model to checkpoint/20230110/intens/3/cp-0019.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 1.0016 - accuracy: 0.7494 - val_loss: 0.7917 - val_accuracy: 0.8030
# Epoch 20/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.9919 - accuracy: 0.7509
# Epoch 20: saving model to checkpoint/20230110/intens/3/cp-0020.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 0.9918 - accuracy: 0.7509 - val_loss: 0.7827 - val_accuracy: 0.8050
# Epoch 21/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.9834 - accuracy: 0.7528
# Epoch 21: saving model to checkpoint/20230110/intens/3/cp-0021.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.9832 - accuracy: 0.7528 - val_loss: 0.7755 - val_accuracy: 0.8066
# Epoch 22/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.9756 - accuracy: 0.7544
# Epoch 22: saving model to checkpoint/20230110/intens/3/cp-0022.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.9754 - accuracy: 0.7544 - val_loss: 0.7701 - val_accuracy: 0.8064
# Epoch 23/50
# 860/860 [==============================] - ETA: 0s - loss: 0.9684 - accuracy: 0.7555
# Epoch 23: saving model to checkpoint/20230110/intens/3/cp-0023.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.9684 - accuracy: 0.7555 - val_loss: 0.7641 - val_accuracy: 0.8086
# Epoch 24/50
# 860/860 [==============================] - ETA: 0s - loss: 0.9621 - accuracy: 0.7568
# Epoch 24: saving model to checkpoint/20230110/intens/3/cp-0024.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 0.9621 - accuracy: 0.7568 - val_loss: 0.7599 - val_accuracy: 0.8088
# Epoch 25/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.9564 - accuracy: 0.7579
# Epoch 25: saving model to checkpoint/20230110/intens/3/cp-0025.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 0.9565 - accuracy: 0.7579 - val_loss: 0.7551 - val_accuracy: 0.8098
# Epoch 26/50
# 860/860 [==============================] - ETA: 0s - loss: 0.9514 - accuracy: 0.7581
# Epoch 26: saving model to checkpoint/20230110/intens/3/cp-0026.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.9514 - accuracy: 0.7581 - val_loss: 0.7517 - val_accuracy: 0.8112
# Epoch 27/50
# 860/860 [==============================] - ETA: 0s - loss: 0.9469 - accuracy: 0.7593
# Epoch 27: saving model to checkpoint/20230110/intens/3/cp-0027.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.9469 - accuracy: 0.7593 - val_loss: 0.7471 - val_accuracy: 0.8114
# Epoch 28/50
# 860/860 [==============================] - ETA: 0s - loss: 0.9428 - accuracy: 0.7602
# Epoch 28: saving model to checkpoint/20230110/intens/3/cp-0028.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.9428 - accuracy: 0.7602 - val_loss: 0.7442 - val_accuracy: 0.8128
# Epoch 29/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.9390 - accuracy: 0.7608
# Epoch 29: saving model to checkpoint/20230110/intens/3/cp-0029.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.9389 - accuracy: 0.7609 - val_loss: 0.7417 - val_accuracy: 0.8120
# Epoch 30/50
# 860/860 [==============================] - ETA: 0s - loss: 0.9355 - accuracy: 0.7615
# Epoch 30: saving model to checkpoint/20230110/intens/3/cp-0030.ckpt
# 860/860 [==============================] - 47s 54ms/step - loss: 0.9355 - accuracy: 0.7615 - val_loss: 0.7384 - val_accuracy: 0.8136
# Epoch 31/50
# 860/860 [==============================] - ETA: 0s - loss: 0.9324 - accuracy: 0.7618
# Epoch 31: saving model to checkpoint/20230110/intens/3/cp-0031.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 0.9324 - accuracy: 0.7618 - val_loss: 0.7363 - val_accuracy: 0.8130
# Epoch 32/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.9297 - accuracy: 0.7620
# Epoch 32: saving model to checkpoint/20230110/intens/3/cp-0032.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 0.9296 - accuracy: 0.7620 - val_loss: 0.7341 - val_accuracy: 0.8140
# Epoch 33/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.9266 - accuracy: 0.7627
# Epoch 33: saving model to checkpoint/20230110/intens/3/cp-0033.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.9269 - accuracy: 0.7627 - val_loss: 0.7321 - val_accuracy: 0.8138
# Epoch 34/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.9245 - accuracy: 0.7631
# Epoch 34: saving model to checkpoint/20230110/intens/3/cp-0034.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 0.9245 - accuracy: 0.7631 - val_loss: 0.7304 - val_accuracy: 0.8142
# Epoch 35/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.9222 - accuracy: 0.7634
# Epoch 35: saving model to checkpoint/20230110/intens/3/cp-0035.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.9222 - accuracy: 0.7634 - val_loss: 0.7288 - val_accuracy: 0.8140
# Epoch 36/50
# 860/860 [==============================] - ETA: 0s - loss: 0.9201 - accuracy: 0.7636
# Epoch 36: saving model to checkpoint/20230110/intens/3/cp-0036.ckpt
# 860/860 [==============================] - 52s 61ms/step - loss: 0.9201 - accuracy: 0.7636 - val_loss: 0.7270 - val_accuracy: 0.8142
# Epoch 37/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.9179 - accuracy: 0.7642
# Epoch 37: saving model to checkpoint/20230110/intens/3/cp-0037.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.9182 - accuracy: 0.7642 - val_loss: 0.7257 - val_accuracy: 0.8144
# Epoch 38/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.9163 - accuracy: 0.7644
# Epoch 38: saving model to checkpoint/20230110/intens/3/cp-0038.ckpt
# 860/860 [==============================] - 45s 52ms/step - loss: 0.9164 - accuracy: 0.7645 - val_loss: 0.7245 - val_accuracy: 0.8146
# Epoch 39/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.9150 - accuracy: 0.7645
# Epoch 39: saving model to checkpoint/20230110/intens/3/cp-0039.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.9148 - accuracy: 0.7645 - val_loss: 0.7227 - val_accuracy: 0.8150
# Epoch 40/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.9136 - accuracy: 0.7648
# Epoch 40: saving model to checkpoint/20230110/intens/3/cp-0040.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.9134 - accuracy: 0.7648 - val_loss: 0.7220 - val_accuracy: 0.8148
# Epoch 41/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.9122 - accuracy: 0.7649
# Epoch 41: saving model to checkpoint/20230110/intens/3/cp-0041.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.9120 - accuracy: 0.7649 - val_loss: 0.7208 - val_accuracy: 0.8156
# Epoch 42/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.9107 - accuracy: 0.7652
# Epoch 42: saving model to checkpoint/20230110/intens/3/cp-0042.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.9107 - accuracy: 0.7651 - val_loss: 0.7196 - val_accuracy: 0.8148
# Epoch 43/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.9096 - accuracy: 0.7655
# Epoch 43: saving model to checkpoint/20230110/intens/3/cp-0043.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.9094 - accuracy: 0.7655 - val_loss: 0.7187 - val_accuracy: 0.8168
# Epoch 44/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.9084 - accuracy: 0.7658
# Epoch 44: saving model to checkpoint/20230110/intens/3/cp-0044.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 0.9083 - accuracy: 0.7658 - val_loss: 0.7177 - val_accuracy: 0.8160
# Epoch 45/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.9072 - accuracy: 0.7659
# Epoch 45: saving model to checkpoint/20230110/intens/3/cp-0045.ckpt
# 860/860 [==============================] - 44s 51ms/step - loss: 0.9071 - accuracy: 0.7659 - val_loss: 0.7169 - val_accuracy: 0.8152
# Epoch 46/50
# 860/860 [==============================] - ETA: 0s - loss: 0.9060 - accuracy: 0.7663
# Epoch 46: saving model to checkpoint/20230110/intens/3/cp-0046.ckpt
# 860/860 [==============================] - 43s 50ms/step - loss: 0.9060 - accuracy: 0.7663 - val_loss: 0.7159 - val_accuracy: 0.8154
# Epoch 47/50
# 438/860 [==============>...............] - ETA: 19s - loss: 0.9069 - accuracy: 0.7662

# %% [markdown]
# # 検光子

# %%
def train(seed, theta, num):
    model_name = "20230110/intens_pol/" + str(num)
    checkpoint_path = "checkpoint/" + model_name + "/cp-{epoch:04d}.ckpt"
    checkpoint_dir = os.path.dirname(checkpoint_path)
    path = "trained_model/"+ model_name

    model = create_model(seed=seed, theta=theta)
    model.summary()
    model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss=tf.keras.losses.sparse_categorical_crossentropy,  # category: sparse_categorical_crossentropy
                  metrics=["accuracy"]
                  )

    epochs = 50
    early_stopping = tf.keras.callbacks.EarlyStopping(
            monitor='loss',
            min_delta=0.0002,
            patience=2,
        )


    # チェックポイントコールバックを作る
    cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                     save_weights_only=True,
                                                     verbose=1)

    logdir = os.path.join("logs", model_name)
    tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

    result = model.fit(x_train,
                       y_train,
                       batch_size=64,
                       epochs=epochs,
                       validation_data=(x_val, y_val),
                       callbacks=[cp_callback, tensorboard_callback]
                       )

    model.save(path)

    df = pd.DataFrame(result.history)
    df.to_csv(path + "/history.csv")



    with open(path + "/config.json", 'w') as f:
        json.dump(model.get_config(), f, indent=4)

# %%
theta = [np.pi, np.pi/2., np.pi/5., np.pi/10., np.pi/100]
for i, _theta in enumerate(theta):
    train(seed=1, theta=_theta, num=i)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28)]          0
#
#  image_resizing (ImageResizi  (None, 100, 100)         0
#  ng)
#
#  intensity_to_electric_field  (None, 2, 100, 100)      0
#   (IntensityToElectricField)
#
#  angular_spectrum (AngularSp  (None, 2, 100, 100)      0
#  ectrum)
#
#  mo (MO)                     (None, 2, 100, 100)       10000
#
#  angular_spectrum_1 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  mo_1 (MO)                   (None, 2, 100, 100)       10000
#
#  angular_spectrum_2 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  mo_2 (MO)                   (None, 2, 100, 100)       10000
#
#  angular_spectrum_3 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  mo_3 (MO)                   (None, 2, 100, 100)       10000
#
#  angular_spectrum_4 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  mo_4 (MO)                   (None, 2, 100, 100)       10000
#
#  angular_spectrum_5 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  polarizer (Polarizer)       (None, 2, 100, 100)       1
#
#  electric_field_to_intensity  (None, 100, 100)         0
#   (ElectricFieldToIntensity)
#
#  mnist_detector (MNISTDetect  (None, 10)               0
#  or)
#
#  softmax (Softmax)           (None, 10)                0
#
# =================================================================
# Total params: 50,001
# Trainable params: 50,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 859/860 [============================>.] - ETA: 0s - loss: 2.2929 - accuracy: 0.6011
# Epoch 1: saving model to checkpoint/20230110/intens_pol/0/cp-0001.ckpt
# 860/860 [==============================] - 55s 57ms/step - loss: 2.2923 - accuracy: 0.6012 - val_loss: 0.3845 - val_accuracy: 0.9010
# Epoch 2/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3719 - accuracy: 0.8962
# Epoch 2: saving model to checkpoint/20230110/intens_pol/0/cp-0002.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.3719 - accuracy: 0.8962 - val_loss: 0.2262 - val_accuracy: 0.9420
# Epoch 3/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.2704 - accuracy: 0.9231
# Epoch 3: saving model to checkpoint/20230110/intens_pol/0/cp-0003.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.2704 - accuracy: 0.9231 - val_loss: 0.1886 - val_accuracy: 0.9490
# Epoch 4/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.2276 - accuracy: 0.9351
# Epoch 4: saving model to checkpoint/20230110/intens_pol/0/cp-0004.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.2276 - accuracy: 0.9352 - val_loss: 0.1680 - val_accuracy: 0.9552
# Epoch 5/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.2020 - accuracy: 0.9423
# Epoch 5: saving model to checkpoint/20230110/intens_pol/0/cp-0005.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.2020 - accuracy: 0.9423 - val_loss: 0.1478 - val_accuracy: 0.9594
# Epoch 6/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1842 - accuracy: 0.9477
# Epoch 6: saving model to checkpoint/20230110/intens_pol/0/cp-0006.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.1842 - accuracy: 0.9477 - val_loss: 0.1443 - val_accuracy: 0.9614
# Epoch 7/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1709 - accuracy: 0.9509
# Epoch 7: saving model to checkpoint/20230110/intens_pol/0/cp-0007.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.1709 - accuracy: 0.9509 - val_loss: 0.1390 - val_accuracy: 0.9622
# Epoch 8/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1621 - accuracy: 0.9526
# Epoch 8: saving model to checkpoint/20230110/intens_pol/0/cp-0008.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.1621 - accuracy: 0.9526 - val_loss: 0.1261 - val_accuracy: 0.9656
# Epoch 9/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1544 - accuracy: 0.9556
# Epoch 9: saving model to checkpoint/20230110/intens_pol/0/cp-0009.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.1545 - accuracy: 0.9555 - val_loss: 0.1229 - val_accuracy: 0.9660
# Epoch 10/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1479 - accuracy: 0.9570
# Epoch 10: saving model to checkpoint/20230110/intens_pol/0/cp-0010.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.1478 - accuracy: 0.9570 - val_loss: 0.1216 - val_accuracy: 0.9664
# Epoch 11/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1435 - accuracy: 0.9580
# Epoch 11: saving model to checkpoint/20230110/intens_pol/0/cp-0011.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.1435 - accuracy: 0.9580 - val_loss: 0.1211 - val_accuracy: 0.9666
# Epoch 12/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1389 - accuracy: 0.9600
# Epoch 12: saving model to checkpoint/20230110/intens_pol/0/cp-0012.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.1390 - accuracy: 0.9600 - val_loss: 0.1152 - val_accuracy: 0.9682
# Epoch 13/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1359 - accuracy: 0.9603
# Epoch 13: saving model to checkpoint/20230110/intens_pol/0/cp-0013.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.1360 - accuracy: 0.9603 - val_loss: 0.1166 - val_accuracy: 0.9704
# Epoch 14/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1328 - accuracy: 0.9612
# Epoch 14: saving model to checkpoint/20230110/intens_pol/0/cp-0014.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.1328 - accuracy: 0.9612 - val_loss: 0.1117 - val_accuracy: 0.9714
# Epoch 15/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1302 - accuracy: 0.9618
# Epoch 15: saving model to checkpoint/20230110/intens_pol/0/cp-0015.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.1302 - accuracy: 0.9617 - val_loss: 0.1130 - val_accuracy: 0.9698
# Epoch 16/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1280 - accuracy: 0.9626
# Epoch 16: saving model to checkpoint/20230110/intens_pol/0/cp-0016.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.1281 - accuracy: 0.9626 - val_loss: 0.1056 - val_accuracy: 0.9720
# Epoch 17/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1259 - accuracy: 0.9634
# Epoch 17: saving model to checkpoint/20230110/intens_pol/0/cp-0017.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.1259 - accuracy: 0.9633 - val_loss: 0.1074 - val_accuracy: 0.9710
# Epoch 18/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1239 - accuracy: 0.9644
# Epoch 18: saving model to checkpoint/20230110/intens_pol/0/cp-0018.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.1239 - accuracy: 0.9644 - val_loss: 0.1045 - val_accuracy: 0.9716
# Epoch 19/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1216 - accuracy: 0.9650
# Epoch 19: saving model to checkpoint/20230110/intens_pol/0/cp-0019.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.1216 - accuracy: 0.9650 - val_loss: 0.1078 - val_accuracy: 0.9722
# Epoch 20/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1210 - accuracy: 0.9644
# Epoch 20: saving model to checkpoint/20230110/intens_pol/0/cp-0020.ckpt
# 860/860 [==============================] - 49s 56ms/step - loss: 0.1210 - accuracy: 0.9644 - val_loss: 0.1090 - val_accuracy: 0.9708
# Epoch 21/50
# 860/860 [==============================] - ETA: 0s - loss: 0.1187 - accuracy: 0.9653
# Epoch 21: saving model to checkpoint/20230110/intens_pol/0/cp-0021.ckpt
# 860/860 [==============================] - 49s 56ms/step - loss: 0.1187 - accuracy: 0.9653 - val_loss: 0.1043 - val_accuracy: 0.9710
# Epoch 22/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1182 - accuracy: 0.9653
# Epoch 22: saving model to checkpoint/20230110/intens_pol/0/cp-0022.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.1181 - accuracy: 0.9653 - val_loss: 0.1132 - val_accuracy: 0.9698
# Epoch 23/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1161 - accuracy: 0.9671
# Epoch 23: saving model to checkpoint/20230110/intens_pol/0/cp-0023.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.1160 - accuracy: 0.9671 - val_loss: 0.1011 - val_accuracy: 0.9706
# Epoch 24/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1162 - accuracy: 0.9662
# Epoch 24: saving model to checkpoint/20230110/intens_pol/0/cp-0024.ckpt
# 860/860 [==============================] - 49s 56ms/step - loss: 0.1162 - accuracy: 0.9662 - val_loss: 0.1049 - val_accuracy: 0.9712
# Epoch 25/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1138 - accuracy: 0.9677
# Epoch 25: saving model to checkpoint/20230110/intens_pol/0/cp-0025.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.1138 - accuracy: 0.9676 - val_loss: 0.1057 - val_accuracy: 0.9726
# Epoch 26/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1139 - accuracy: 0.9671
# Epoch 26: saving model to checkpoint/20230110/intens_pol/0/cp-0026.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.1139 - accuracy: 0.9671 - val_loss: 0.1027 - val_accuracy: 0.9704
# Epoch 27/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1133 - accuracy: 0.9669
# Epoch 27: saving model to checkpoint/20230110/intens_pol/0/cp-0027.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.1133 - accuracy: 0.9669 - val_loss: 0.1029 - val_accuracy: 0.9718
# Epoch 28/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1117 - accuracy: 0.9677
# Epoch 28: saving model to checkpoint/20230110/intens_pol/0/cp-0028.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.1116 - accuracy: 0.9677 - val_loss: 0.1019 - val_accuracy: 0.9734
# Epoch 29/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1109 - accuracy: 0.9682
# Epoch 29: saving model to checkpoint/20230110/intens_pol/0/cp-0029.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.1110 - accuracy: 0.9682 - val_loss: 0.1014 - val_accuracy: 0.9732
# Epoch 30/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1105 - accuracy: 0.9682
# Epoch 30: saving model to checkpoint/20230110/intens_pol/0/cp-0030.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.1105 - accuracy: 0.9682 - val_loss: 0.0995 - val_accuracy: 0.9730
# Epoch 31/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1093 - accuracy: 0.9683
# Epoch 31: saving model to checkpoint/20230110/intens_pol/0/cp-0031.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.1094 - accuracy: 0.9683 - val_loss: 0.1019 - val_accuracy: 0.9724
# Epoch 32/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1086 - accuracy: 0.9679
# Epoch 32: saving model to checkpoint/20230110/intens_pol/0/cp-0032.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.1087 - accuracy: 0.9679 - val_loss: 0.0981 - val_accuracy: 0.9734
# Epoch 33/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1080 - accuracy: 0.9687
# Epoch 33: saving model to checkpoint/20230110/intens_pol/0/cp-0033.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.1081 - accuracy: 0.9687 - val_loss: 0.1021 - val_accuracy: 0.9712
# Epoch 34/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1076 - accuracy: 0.9683
# Epoch 34: saving model to checkpoint/20230110/intens_pol/0/cp-0034.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.1076 - accuracy: 0.9683 - val_loss: 0.1024 - val_accuracy: 0.9718
# Epoch 35/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1070 - accuracy: 0.9688
# Epoch 35: saving model to checkpoint/20230110/intens_pol/0/cp-0035.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.1069 - accuracy: 0.9688 - val_loss: 0.0987 - val_accuracy: 0.9718
# Epoch 36/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1065 - accuracy: 0.9695
# Epoch 36: saving model to checkpoint/20230110/intens_pol/0/cp-0036.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.1064 - accuracy: 0.9695 - val_loss: 0.0993 - val_accuracy: 0.9734
# Epoch 37/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1056 - accuracy: 0.9692
# Epoch 37: saving model to checkpoint/20230110/intens_pol/0/cp-0037.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.1056 - accuracy: 0.9693 - val_loss: 0.0977 - val_accuracy: 0.9746
# Epoch 38/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1056 - accuracy: 0.9698
# Epoch 38: saving model to checkpoint/20230110/intens_pol/0/cp-0038.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.1056 - accuracy: 0.9697 - val_loss: 0.1001 - val_accuracy: 0.9746
# Epoch 39/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1052 - accuracy: 0.9695
# Epoch 39: saving model to checkpoint/20230110/intens_pol/0/cp-0039.ckpt
# 860/860 [==============================] - 49s 56ms/step - loss: 0.1052 - accuracy: 0.9695 - val_loss: 0.0988 - val_accuracy: 0.9754
# Epoch 40/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1044 - accuracy: 0.9703
# Epoch 40: saving model to checkpoint/20230110/intens_pol/0/cp-0040.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.1043 - accuracy: 0.9703 - val_loss: 0.1048 - val_accuracy: 0.9714
# Epoch 41/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1043 - accuracy: 0.9700
# Epoch 41: saving model to checkpoint/20230110/intens_pol/0/cp-0041.ckpt
# 860/860 [==============================] - 53s 62ms/step - loss: 0.1043 - accuracy: 0.9700 - val_loss: 0.0967 - val_accuracy: 0.9744
# Epoch 42/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1032 - accuracy: 0.9703
# Epoch 42: saving model to checkpoint/20230110/intens_pol/0/cp-0042.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.1031 - accuracy: 0.9703 - val_loss: 0.1012 - val_accuracy: 0.9716
# Epoch 43/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1029 - accuracy: 0.9702
# Epoch 43: saving model to checkpoint/20230110/intens_pol/0/cp-0043.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.1029 - accuracy: 0.9702 - val_loss: 0.1036 - val_accuracy: 0.9722
# Epoch 44/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.1034 - accuracy: 0.9703
# Epoch 44: saving model to checkpoint/20230110/intens_pol/0/cp-0044.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.1034 - accuracy: 0.9703 - val_loss: 0.0967 - val_accuracy: 0.9748
# Epoch 45/50
# 109/860 [==>...........................] - ETA: 39s - loss: 0.1035 - accuracy: 0.9695

# %% [markdown]
# # 回転角

# %%
def create_model(**kwargs):
    shape = (100, 100)
    theta = kwargs["theta"]
    eta = 0.
    tf.random.set_seed(kwargs["seed"])
    inputs = tf.keras.Input((28, 28))
    x = ImageResizing(shape)(inputs)
    x = IntensityToElectricField(shape)(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=z, d=d, n=n, method='expand')(x)
    x = MO(shape, limitation='sin', theta=theta, eta=eta)(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=z, d=d, n=n, method='expand')(x)
    x = MO(shape, limitation='sin', theta=theta, eta=eta)(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=z, d=d, n=n, method='expand')(x)
    x = MO(shape, limitation='sin', theta=theta, eta=eta)(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=z, d=d, n=n, method='expand')(x)
    x = MO(shape, limitation='sin', theta=theta, eta=eta)(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=z, d=d, n=n, method='expand')(x)
    x = MO(shape, limitation='sin', theta=theta, eta=eta)(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=z, d=d, n=n, method='expand')(x)
    x = FaradayRotationByStokes(shape)(x)
    x = MNISTDetector(shape)(x)
    x = tf.keras.layers.Softmax()(x)
    model = tf.keras.Model(inputs, x)
    return model

# %%
def train(seed, theta, num):
    model_name = "20230110/angle/" + str(num)
    checkpoint_path = "checkpoint/" + model_name + "/cp-{epoch:04d}.ckpt"
    checkpoint_dir = os.path.dirname(checkpoint_path)
    path = "trained_model/"+ model_name

    model = create_model(seed=seed, theta=theta)
    model.summary()
    model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss=tf.keras.losses.sparse_categorical_crossentropy,  # category: sparse_categorical_crossentropy
                  metrics=["accuracy"]
                  )

    epochs = 50
    early_stopping = tf.keras.callbacks.EarlyStopping(
            monitor='loss',
            min_delta=0.0002,
            patience=2,
        )


    # チェックポイントコールバックを作る
    cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                     save_weights_only=True,
                                                     verbose=1)

    logdir = os.path.join("logs", model_name)
    tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

    result = model.fit(x_train,
                       y_train,
                       batch_size=64,
                       epochs=epochs,
                       validation_data=(x_val, y_val),
                       callbacks=[cp_callback, tensorboard_callback]
                       )

    model.save(path)

    df = pd.DataFrame(result.history)
    df.to_csv(path + "/history.csv")



    with open(path + "/config.json", 'w') as f:
        json.dump(model.get_config(), f, indent=4)

# %%
theta = [np.pi/40, np.pi/100., np.pi/200., np.pi/500., np.pi/1000]
for i, _theta in enumerate(theta):
    train(seed=1, theta=_theta, num=i)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28)]          0
#
#  image_resizing_1 (ImageResi  (None, 100, 100)         0
#  zing)
#
#  intensity_to_electric_field  (None, 2, 100, 100)      0
#  _1 (IntensityToElectricFiel
#  d)
#
#  angular_spectrum_6 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  mo_5 (MO)                   (None, 2, 100, 100)       10000
#
#  angular_spectrum_7 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  mo_6 (MO)                   (None, 2, 100, 100)       10000
#
#  angular_spectrum_8 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  mo_7 (MO)                   (None, 2, 100, 100)       10000
#
#  angular_spectrum_9 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  mo_8 (MO)                   (None, 2, 100, 100)       10000
#
#  angular_spectrum_10 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  mo_9 (MO)                   (None, 2, 100, 100)       10000
#
#  angular_spectrum_11 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  faraday_rotation_by_stokes_  (None, 100, 100)         0
#  1 (FaradayRotationByStokes)
#
#  mnist_detector_1 (MNISTDete  (None, 10)               0
#  ctor)
#
#  softmax_1 (Softmax)         (None, 10)                0
#
# =================================================================
# Total params: 50,000
# Trainable params: 50,000
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.0941 - accuracy: 0.7001
# Epoch 1: saving model to checkpoint/20230110/angle/0/cp-0001.ckpt
# 860/860 [==============================] - 53s 58ms/step - loss: 1.0939 - accuracy: 0.7002 - val_loss: 0.6901 - val_accuracy: 0.8378
# Epoch 2/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7060 - accuracy: 0.8091
# Epoch 2: saving model to checkpoint/20230110/angle/0/cp-0002.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.7059 - accuracy: 0.8092 - val_loss: 0.5518 - val_accuracy: 0.8638
# Epoch 3/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.6135 - accuracy: 0.8330
# Epoch 3: saving model to checkpoint/20230110/angle/0/cp-0003.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.6134 - accuracy: 0.8330 - val_loss: 0.4969 - val_accuracy: 0.8756
# Epoch 4/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5649 - accuracy: 0.8448
# Epoch 4: saving model to checkpoint/20230110/angle/0/cp-0004.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.5648 - accuracy: 0.8448 - val_loss: 0.4591 - val_accuracy: 0.8826
# Epoch 5/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5330 - accuracy: 0.8523
# Epoch 5: saving model to checkpoint/20230110/angle/0/cp-0005.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.5330 - accuracy: 0.8523 - val_loss: 0.4327 - val_accuracy: 0.8906
# Epoch 6/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5096 - accuracy: 0.8593
# Epoch 6: saving model to checkpoint/20230110/angle/0/cp-0006.ckpt
# 860/860 [==============================] - 51s 59ms/step - loss: 0.5096 - accuracy: 0.8593 - val_loss: 0.4167 - val_accuracy: 0.8946
# Epoch 7/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4930 - accuracy: 0.8619
# Epoch 7: saving model to checkpoint/20230110/angle/0/cp-0007.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.4929 - accuracy: 0.8619 - val_loss: 0.4006 - val_accuracy: 0.8978
# Epoch 8/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4792 - accuracy: 0.8662
# Epoch 8: saving model to checkpoint/20230110/angle/0/cp-0008.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.4792 - accuracy: 0.8663 - val_loss: 0.3914 - val_accuracy: 0.9010
# Epoch 9/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4677 - accuracy: 0.8695
# Epoch 9: saving model to checkpoint/20230110/angle/0/cp-0009.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.4680 - accuracy: 0.8695 - val_loss: 0.3820 - val_accuracy: 0.9020
# Epoch 10/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4585 - accuracy: 0.8718
# Epoch 10: saving model to checkpoint/20230110/angle/0/cp-0010.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.4585 - accuracy: 0.8718 - val_loss: 0.3774 - val_accuracy: 0.9042
# Epoch 11/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4504 - accuracy: 0.8732
# Epoch 11: saving model to checkpoint/20230110/angle/0/cp-0011.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.4505 - accuracy: 0.8732 - val_loss: 0.3677 - val_accuracy: 0.9068
# Epoch 12/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4426 - accuracy: 0.8762
# Epoch 12: saving model to checkpoint/20230110/angle/0/cp-0012.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.4428 - accuracy: 0.8761 - val_loss: 0.3639 - val_accuracy: 0.9062
# Epoch 13/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4369 - accuracy: 0.8768
# Epoch 13: saving model to checkpoint/20230110/angle/0/cp-0013.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.4370 - accuracy: 0.8767 - val_loss: 0.3584 - val_accuracy: 0.9086
# Epoch 14/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4315 - accuracy: 0.8781
# Epoch 14: saving model to checkpoint/20230110/angle/0/cp-0014.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.4316 - accuracy: 0.8781 - val_loss: 0.3523 - val_accuracy: 0.9064
# Epoch 15/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4260 - accuracy: 0.8800
# Epoch 15: saving model to checkpoint/20230110/angle/0/cp-0015.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.4260 - accuracy: 0.8800 - val_loss: 0.3487 - val_accuracy: 0.9082
# Epoch 16/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4205 - accuracy: 0.8820
# Epoch 16: saving model to checkpoint/20230110/angle/0/cp-0016.ckpt
# 860/860 [==============================] - 49s 58ms/step - loss: 0.4206 - accuracy: 0.8820 - val_loss: 0.3460 - val_accuracy: 0.9066
# Epoch 17/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4172 - accuracy: 0.8830
# Epoch 17: saving model to checkpoint/20230110/angle/0/cp-0017.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.4172 - accuracy: 0.8831 - val_loss: 0.3422 - val_accuracy: 0.9096
# Epoch 18/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4131 - accuracy: 0.8836
# Epoch 18: saving model to checkpoint/20230110/angle/0/cp-0018.ckpt
# 860/860 [==============================] - 50s 58ms/step - loss: 0.4130 - accuracy: 0.8837 - val_loss: 0.3373 - val_accuracy: 0.9108
# Epoch 19/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4096 - accuracy: 0.8841
# Epoch 19: saving model to checkpoint/20230110/angle/0/cp-0019.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.4096 - accuracy: 0.8841 - val_loss: 0.3369 - val_accuracy: 0.9118
# Epoch 20/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4068 - accuracy: 0.8851
# Epoch 20: saving model to checkpoint/20230110/angle/0/cp-0020.ckpt
# 860/860 [==============================] - 50s 58ms/step - loss: 0.4068 - accuracy: 0.8851 - val_loss: 0.3337 - val_accuracy: 0.9112
# Epoch 21/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4035 - accuracy: 0.8859
# Epoch 21: saving model to checkpoint/20230110/angle/0/cp-0021.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.4035 - accuracy: 0.8859 - val_loss: 0.3330 - val_accuracy: 0.9100
# Epoch 22/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4012 - accuracy: 0.8867
# Epoch 22: saving model to checkpoint/20230110/angle/0/cp-0022.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.4011 - accuracy: 0.8867 - val_loss: 0.3269 - val_accuracy: 0.9128
# Epoch 23/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3984 - accuracy: 0.8872
# Epoch 23: saving model to checkpoint/20230110/angle/0/cp-0023.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.3984 - accuracy: 0.8872 - val_loss: 0.3254 - val_accuracy: 0.9142
# Epoch 24/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3962 - accuracy: 0.8875
# Epoch 24: saving model to checkpoint/20230110/angle/0/cp-0024.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.3962 - accuracy: 0.8875 - val_loss: 0.3264 - val_accuracy: 0.9144
# Epoch 25/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3941 - accuracy: 0.8885
# Epoch 25: saving model to checkpoint/20230110/angle/0/cp-0025.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.3942 - accuracy: 0.8884 - val_loss: 0.3273 - val_accuracy: 0.9160
# Epoch 26/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3922 - accuracy: 0.8892
# Epoch 26: saving model to checkpoint/20230110/angle/0/cp-0026.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.3921 - accuracy: 0.8892 - val_loss: 0.3236 - val_accuracy: 0.9164
# Epoch 27/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3901 - accuracy: 0.8902
# Epoch 27: saving model to checkpoint/20230110/angle/0/cp-0027.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.3901 - accuracy: 0.8902 - val_loss: 0.3218 - val_accuracy: 0.9142
# Epoch 28/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3880 - accuracy: 0.8899
# Epoch 28: saving model to checkpoint/20230110/angle/0/cp-0028.ckpt
# 860/860 [==============================] - 49s 56ms/step - loss: 0.3880 - accuracy: 0.8899 - val_loss: 0.3203 - val_accuracy: 0.9158
# Epoch 29/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3859 - accuracy: 0.8906
# Epoch 29: saving model to checkpoint/20230110/angle/0/cp-0029.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.3860 - accuracy: 0.8906 - val_loss: 0.3204 - val_accuracy: 0.9162
# Epoch 30/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3850 - accuracy: 0.8916
# Epoch 30: saving model to checkpoint/20230110/angle/0/cp-0030.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.3850 - accuracy: 0.8916 - val_loss: 0.3190 - val_accuracy: 0.9164
# Epoch 31/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3834 - accuracy: 0.8924
# Epoch 31: saving model to checkpoint/20230110/angle/0/cp-0031.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.3834 - accuracy: 0.8924 - val_loss: 0.3162 - val_accuracy: 0.9166
# Epoch 32/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3810 - accuracy: 0.8927
# Epoch 32: saving model to checkpoint/20230110/angle/0/cp-0032.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.3810 - accuracy: 0.8927 - val_loss: 0.3168 - val_accuracy: 0.9142
# Epoch 33/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3803 - accuracy: 0.8928
# Epoch 33: saving model to checkpoint/20230110/angle/0/cp-0033.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.3803 - accuracy: 0.8927 - val_loss: 0.3146 - val_accuracy: 0.9176
# Epoch 34/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3786 - accuracy: 0.8935
# Epoch 34: saving model to checkpoint/20230110/angle/0/cp-0034.ckpt
# 860/860 [==============================] - 49s 56ms/step - loss: 0.3786 - accuracy: 0.8935 - val_loss: 0.3159 - val_accuracy: 0.9180
# Epoch 35/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3777 - accuracy: 0.8931
# Epoch 35: saving model to checkpoint/20230110/angle/0/cp-0035.ckpt
# 860/860 [==============================] - 49s 56ms/step - loss: 0.3777 - accuracy: 0.8931 - val_loss: 0.3131 - val_accuracy: 0.9196
# Epoch 36/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3765 - accuracy: 0.8941
# Epoch 36: saving model to checkpoint/20230110/angle/0/cp-0036.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.3764 - accuracy: 0.8942 - val_loss: 0.3135 - val_accuracy: 0.9178
# Epoch 37/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3748 - accuracy: 0.8937
# Epoch 37: saving model to checkpoint/20230110/angle/0/cp-0037.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.3749 - accuracy: 0.8937 - val_loss: 0.3138 - val_accuracy: 0.9174
# Epoch 38/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3742 - accuracy: 0.8946
# Epoch 38: saving model to checkpoint/20230110/angle/0/cp-0038.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.3742 - accuracy: 0.8946 - val_loss: 0.3149 - val_accuracy: 0.9152
# Epoch 39/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3727 - accuracy: 0.8946
# Epoch 39: saving model to checkpoint/20230110/angle/0/cp-0039.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.3727 - accuracy: 0.8946 - val_loss: 0.3127 - val_accuracy: 0.9178
# Epoch 40/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3714 - accuracy: 0.8954
# Epoch 40: saving model to checkpoint/20230110/angle/0/cp-0040.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.3713 - accuracy: 0.8954 - val_loss: 0.3117 - val_accuracy: 0.9168
# Epoch 41/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3709 - accuracy: 0.8952
# Epoch 41: saving model to checkpoint/20230110/angle/0/cp-0041.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.3709 - accuracy: 0.8952 - val_loss: 0.3115 - val_accuracy: 0.9168
# Epoch 42/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3695 - accuracy: 0.8966
# Epoch 42: saving model to checkpoint/20230110/angle/0/cp-0042.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.3694 - accuracy: 0.8966 - val_loss: 0.3081 - val_accuracy: 0.9194
# Epoch 43/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3686 - accuracy: 0.8964
# Epoch 43: saving model to checkpoint/20230110/angle/0/cp-0043.ckpt
# 860/860 [==============================] - 49s 56ms/step - loss: 0.3685 - accuracy: 0.8964 - val_loss: 0.3069 - val_accuracy: 0.9168
# Epoch 44/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3679 - accuracy: 0.8964
# Epoch 44: saving model to checkpoint/20230110/angle/0/cp-0044.ckpt
# 860/860 [==============================] - 49s 56ms/step - loss: 0.3678 - accuracy: 0.8964 - val_loss: 0.3080 - val_accuracy: 0.9186
# Epoch 45/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3668 - accuracy: 0.8970
# Epoch 45: saving model to checkpoint/20230110/angle/0/cp-0045.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.3669 - accuracy: 0.8970 - val_loss: 0.3074 - val_accuracy: 0.9198
# Epoch 46/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3665 - accuracy: 0.8971
# Epoch 46: saving model to checkpoint/20230110/angle/0/cp-0046.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.3664 - accuracy: 0.8971 - val_loss: 0.3047 - val_accuracy: 0.9182
# Epoch 47/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3651 - accuracy: 0.8973
# Epoch 47: saving model to checkpoint/20230110/angle/0/cp-0047.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.3651 - accuracy: 0.8973 - val_loss: 0.3057 - val_accuracy: 0.9192
# Epoch 48/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3646 - accuracy: 0.8978
# Epoch 48: saving model to checkpoint/20230110/angle/0/cp-0048.ckpt
# 860/860 [==============================] - 53s 62ms/step - loss: 0.3646 - accuracy: 0.8978 - val_loss: 0.3052 - val_accuracy: 0.9192
# Epoch 49/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3638 - accuracy: 0.8980
# Epoch 49: saving model to checkpoint/20230110/angle/0/cp-0049.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.3639 - accuracy: 0.8979 - val_loss: 0.3042 - val_accuracy: 0.9188
# Epoch 50/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.3631 - accuracy: 0.8976
# Epoch 50: saving model to checkpoint/20230110/angle/0/cp-0050.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.3631 - accuracy: 0.8976 - val_loss: 0.3068 - val_accuracy: 0.9172
# WARNING:absl:Found untraced functions such as get_limited_eta, get_limited_theta, get_limited_eta, get_limited_theta, get_limited_eta while saving (showing 5 of 11). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_model/20230110/angle/0/assets
# INFO:tensorflow:Assets written to: trained_model/20230110/angle/0/assets
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 28, 28)]          0
#
#  image_resizing_2 (ImageResi  (None, 100, 100)         0
#  zing)
#
#  intensity_to_electric_field  (None, 2, 100, 100)      0
#  _2 (IntensityToElectricFiel
#  d)
#
#  angular_spectrum_12 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  mo_10 (MO)                  (None, 2, 100, 100)       10000
#
#  angular_spectrum_13 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  mo_11 (MO)                  (None, 2, 100, 100)       10000
#
#  angular_spectrum_14 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  mo_12 (MO)                  (None, 2, 100, 100)       10000
#
#  angular_spectrum_15 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  mo_13 (MO)                  (None, 2, 100, 100)       10000
#
#  angular_spectrum_16 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  mo_14 (MO)                  (None, 2, 100, 100)       10000
#
#  angular_spectrum_17 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  faraday_rotation_by_stokes_  (None, 100, 100)         0
#  2 (FaradayRotationByStokes)
#
#  mnist_detector_2 (MNISTDete  (None, 10)               0
#  ctor)
#
#  softmax_2 (Softmax)         (None, 10)                0
#
# =================================================================
# Total params: 50,000
# Trainable params: 50,000
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.3954 - accuracy: 0.6205
# Epoch 1: saving model to checkpoint/20230110/angle/1/cp-0001.ckpt
# 860/860 [==============================] - 52s 57ms/step - loss: 1.3952 - accuracy: 0.6205 - val_loss: 0.9690 - val_accuracy: 0.7672
# Epoch 2/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.9360 - accuracy: 0.7486
# Epoch 2: saving model to checkpoint/20230110/angle/1/cp-0002.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.9359 - accuracy: 0.7487 - val_loss: 0.7625 - val_accuracy: 0.8182
# Epoch 3/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.8016 - accuracy: 0.7871
# Epoch 3: saving model to checkpoint/20230110/angle/1/cp-0003.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.8015 - accuracy: 0.7871 - val_loss: 0.6694 - val_accuracy: 0.8436
# Epoch 4/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7321 - accuracy: 0.8053
# Epoch 4: saving model to checkpoint/20230110/angle/1/cp-0004.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.7321 - accuracy: 0.8053 - val_loss: 0.6149 - val_accuracy: 0.8510
# Epoch 5/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.6878 - accuracy: 0.8157
# Epoch 5: saving model to checkpoint/20230110/angle/1/cp-0005.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.6878 - accuracy: 0.8157 - val_loss: 0.5777 - val_accuracy: 0.8584
# Epoch 6/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.6564 - accuracy: 0.8249
# Epoch 6: saving model to checkpoint/20230110/angle/1/cp-0006.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.6564 - accuracy: 0.8249 - val_loss: 0.5545 - val_accuracy: 0.8610
# Epoch 7/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.6335 - accuracy: 0.8297
# Epoch 7: saving model to checkpoint/20230110/angle/1/cp-0007.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.6335 - accuracy: 0.8298 - val_loss: 0.5351 - val_accuracy: 0.8692
# Epoch 8/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.6161 - accuracy: 0.8343
# Epoch 8: saving model to checkpoint/20230110/angle/1/cp-0008.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.6162 - accuracy: 0.8344 - val_loss: 0.5199 - val_accuracy: 0.8730
# Epoch 9/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.6017 - accuracy: 0.8388
# Epoch 9: saving model to checkpoint/20230110/angle/1/cp-0009.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.6019 - accuracy: 0.8387 - val_loss: 0.5087 - val_accuracy: 0.8726
# Epoch 10/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5910 - accuracy: 0.8410
# Epoch 10: saving model to checkpoint/20230110/angle/1/cp-0010.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.5909 - accuracy: 0.8411 - val_loss: 0.4987 - val_accuracy: 0.8756
# Epoch 11/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5806 - accuracy: 0.8436
# Epoch 11: saving model to checkpoint/20230110/angle/1/cp-0011.ckpt
# 860/860 [==============================] - 49s 56ms/step - loss: 0.5807 - accuracy: 0.8436 - val_loss: 0.4895 - val_accuracy: 0.8786
# Epoch 12/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5727 - accuracy: 0.8462
# Epoch 12: saving model to checkpoint/20230110/angle/1/cp-0012.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.5729 - accuracy: 0.8462 - val_loss: 0.4833 - val_accuracy: 0.8812
# Epoch 13/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5659 - accuracy: 0.8476
# Epoch 13: saving model to checkpoint/20230110/angle/1/cp-0013.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.5660 - accuracy: 0.8476 - val_loss: 0.4773 - val_accuracy: 0.8816
# Epoch 14/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5599 - accuracy: 0.8492
# Epoch 14: saving model to checkpoint/20230110/angle/1/cp-0014.ckpt
# 860/860 [==============================] - 49s 58ms/step - loss: 0.5599 - accuracy: 0.8492 - val_loss: 0.4712 - val_accuracy: 0.8828
# Epoch 15/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5545 - accuracy: 0.8507
# Epoch 15: saving model to checkpoint/20230110/angle/1/cp-0015.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.5545 - accuracy: 0.8507 - val_loss: 0.4676 - val_accuracy: 0.8844
# Epoch 16/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5498 - accuracy: 0.8522
# Epoch 16: saving model to checkpoint/20230110/angle/1/cp-0016.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.5498 - accuracy: 0.8522 - val_loss: 0.4635 - val_accuracy: 0.8850
# Epoch 17/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5459 - accuracy: 0.8533
# Epoch 17: saving model to checkpoint/20230110/angle/1/cp-0017.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.5458 - accuracy: 0.8533 - val_loss: 0.4595 - val_accuracy: 0.8856
# Epoch 18/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5422 - accuracy: 0.8541
# Epoch 18: saving model to checkpoint/20230110/angle/1/cp-0018.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.5422 - accuracy: 0.8541 - val_loss: 0.4557 - val_accuracy: 0.8866
# Epoch 19/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5391 - accuracy: 0.8553
# Epoch 19: saving model to checkpoint/20230110/angle/1/cp-0019.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.5391 - accuracy: 0.8553 - val_loss: 0.4535 - val_accuracy: 0.8876
# Epoch 20/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5362 - accuracy: 0.8566
# Epoch 20: saving model to checkpoint/20230110/angle/1/cp-0020.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.5361 - accuracy: 0.8566 - val_loss: 0.4518 - val_accuracy: 0.8878
# Epoch 21/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5337 - accuracy: 0.8566
# Epoch 21: saving model to checkpoint/20230110/angle/1/cp-0021.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.5336 - accuracy: 0.8566 - val_loss: 0.4493 - val_accuracy: 0.8868
# Epoch 22/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5310 - accuracy: 0.8576
# Epoch 22: saving model to checkpoint/20230110/angle/1/cp-0022.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.5310 - accuracy: 0.8576 - val_loss: 0.4468 - val_accuracy: 0.8898
# Epoch 23/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5290 - accuracy: 0.8582
# Epoch 23: saving model to checkpoint/20230110/angle/1/cp-0023.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.5289 - accuracy: 0.8582 - val_loss: 0.4459 - val_accuracy: 0.8898
# Epoch 24/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5271 - accuracy: 0.8589
# Epoch 24: saving model to checkpoint/20230110/angle/1/cp-0024.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.5270 - accuracy: 0.8590 - val_loss: 0.4439 - val_accuracy: 0.8904
# Epoch 25/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5254 - accuracy: 0.8594
# Epoch 25: saving model to checkpoint/20230110/angle/1/cp-0025.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.5255 - accuracy: 0.8594 - val_loss: 0.4429 - val_accuracy: 0.8898
# Epoch 26/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5236 - accuracy: 0.8598
# Epoch 26: saving model to checkpoint/20230110/angle/1/cp-0026.ckpt
# 860/860 [==============================] - 49s 56ms/step - loss: 0.5235 - accuracy: 0.8598 - val_loss: 0.4404 - val_accuracy: 0.8898
# Epoch 27/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5222 - accuracy: 0.8602
# Epoch 27: saving model to checkpoint/20230110/angle/1/cp-0027.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.5221 - accuracy: 0.8602 - val_loss: 0.4388 - val_accuracy: 0.8912
# Epoch 28/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5208 - accuracy: 0.8610
# Epoch 28: saving model to checkpoint/20230110/angle/1/cp-0028.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.5208 - accuracy: 0.8610 - val_loss: 0.4384 - val_accuracy: 0.8916
# Epoch 29/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5193 - accuracy: 0.8604
# Epoch 29: saving model to checkpoint/20230110/angle/1/cp-0029.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.5193 - accuracy: 0.8604 - val_loss: 0.4370 - val_accuracy: 0.8916
# Epoch 30/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5182 - accuracy: 0.8616
# Epoch 30: saving model to checkpoint/20230110/angle/1/cp-0030.ckpt
# 860/860 [==============================] - 50s 58ms/step - loss: 0.5182 - accuracy: 0.8616 - val_loss: 0.4362 - val_accuracy: 0.8926
# Epoch 31/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5170 - accuracy: 0.8619
# Epoch 31: saving model to checkpoint/20230110/angle/1/cp-0031.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.5170 - accuracy: 0.8619 - val_loss: 0.4342 - val_accuracy: 0.8916
# Epoch 32/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5158 - accuracy: 0.8621
# Epoch 32: saving model to checkpoint/20230110/angle/1/cp-0032.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.5158 - accuracy: 0.8621 - val_loss: 0.4344 - val_accuracy: 0.8908
# Epoch 33/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5147 - accuracy: 0.8621
# Epoch 33: saving model to checkpoint/20230110/angle/1/cp-0033.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.5147 - accuracy: 0.8621 - val_loss: 0.4320 - val_accuracy: 0.8932
# Epoch 34/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5136 - accuracy: 0.8628
# Epoch 34: saving model to checkpoint/20230110/angle/1/cp-0034.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.5136 - accuracy: 0.8628 - val_loss: 0.4322 - val_accuracy: 0.8942
# Epoch 35/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5129 - accuracy: 0.8632
# Epoch 35: saving model to checkpoint/20230110/angle/1/cp-0035.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.5128 - accuracy: 0.8633 - val_loss: 0.4318 - val_accuracy: 0.8930
# Epoch 36/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5123 - accuracy: 0.8630
# Epoch 36: saving model to checkpoint/20230110/angle/1/cp-0036.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.5122 - accuracy: 0.8631 - val_loss: 0.4314 - val_accuracy: 0.8922
# Epoch 37/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5113 - accuracy: 0.8635
# Epoch 37: saving model to checkpoint/20230110/angle/1/cp-0037.ckpt
# 860/860 [==============================] - 49s 56ms/step - loss: 0.5114 - accuracy: 0.8635 - val_loss: 0.4312 - val_accuracy: 0.8944
# Epoch 38/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5105 - accuracy: 0.8639
# Epoch 38: saving model to checkpoint/20230110/angle/1/cp-0038.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.5105 - accuracy: 0.8639 - val_loss: 0.4301 - val_accuracy: 0.8922
# Epoch 39/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5100 - accuracy: 0.8642
# Epoch 39: saving model to checkpoint/20230110/angle/1/cp-0039.ckpt
# 860/860 [==============================] - 60s 70ms/step - loss: 0.5099 - accuracy: 0.8643 - val_loss: 0.4296 - val_accuracy: 0.8944
# Epoch 40/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5091 - accuracy: 0.8642
# Epoch 40: saving model to checkpoint/20230110/angle/1/cp-0040.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.5091 - accuracy: 0.8642 - val_loss: 0.4289 - val_accuracy: 0.8928
# Epoch 41/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5086 - accuracy: 0.8642
# Epoch 41: saving model to checkpoint/20230110/angle/1/cp-0041.ckpt
# 860/860 [==============================] - 49s 56ms/step - loss: 0.5086 - accuracy: 0.8642 - val_loss: 0.4290 - val_accuracy: 0.8938
# Epoch 42/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5078 - accuracy: 0.8642
# Epoch 42: saving model to checkpoint/20230110/angle/1/cp-0042.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.5078 - accuracy: 0.8643 - val_loss: 0.4274 - val_accuracy: 0.8948
# Epoch 43/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5071 - accuracy: 0.8650
# Epoch 43: saving model to checkpoint/20230110/angle/1/cp-0043.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.5071 - accuracy: 0.8649 - val_loss: 0.4266 - val_accuracy: 0.8940
# Epoch 44/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5067 - accuracy: 0.8649
# Epoch 44: saving model to checkpoint/20230110/angle/1/cp-0044.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.5067 - accuracy: 0.8648 - val_loss: 0.4276 - val_accuracy: 0.8960
# Epoch 45/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5061 - accuracy: 0.8649
# Epoch 45: saving model to checkpoint/20230110/angle/1/cp-0045.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.5062 - accuracy: 0.8648 - val_loss: 0.4263 - val_accuracy: 0.8958
# Epoch 46/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5056 - accuracy: 0.8651
# Epoch 46: saving model to checkpoint/20230110/angle/1/cp-0046.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.5056 - accuracy: 0.8651 - val_loss: 0.4253 - val_accuracy: 0.8942
# Epoch 47/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5051 - accuracy: 0.8655
# Epoch 47: saving model to checkpoint/20230110/angle/1/cp-0047.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.5051 - accuracy: 0.8655 - val_loss: 0.4266 - val_accuracy: 0.8960
# Epoch 48/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5046 - accuracy: 0.8649
# Epoch 48: saving model to checkpoint/20230110/angle/1/cp-0048.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.5046 - accuracy: 0.8649 - val_loss: 0.4249 - val_accuracy: 0.8958
# Epoch 49/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5043 - accuracy: 0.8658
# Epoch 49: saving model to checkpoint/20230110/angle/1/cp-0049.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.5044 - accuracy: 0.8657 - val_loss: 0.4253 - val_accuracy: 0.8954
# Epoch 50/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5041 - accuracy: 0.8656
# Epoch 50: saving model to checkpoint/20230110/angle/1/cp-0050.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.5042 - accuracy: 0.8656 - val_loss: 0.4245 - val_accuracy: 0.8948
# WARNING:absl:Found untraced functions such as get_limited_eta, get_limited_theta, get_limited_eta, get_limited_theta, get_limited_eta while saving (showing 5 of 11). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_model/20230110/angle/1/assets
# INFO:tensorflow:Assets written to: trained_model/20230110/angle/1/assets
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 28, 28)]          0
#
#  image_resizing_3 (ImageResi  (None, 100, 100)         0
#  zing)
#
#  intensity_to_electric_field  (None, 2, 100, 100)      0
#  _3 (IntensityToElectricFiel
#  d)
#
#  angular_spectrum_18 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  mo_15 (MO)                  (None, 2, 100, 100)       10000
#
#  angular_spectrum_19 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  mo_16 (MO)                  (None, 2, 100, 100)       10000
#
#  angular_spectrum_20 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  mo_17 (MO)                  (None, 2, 100, 100)       10000
#
#  angular_spectrum_21 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  mo_18 (MO)                  (None, 2, 100, 100)       10000
#
#  angular_spectrum_22 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  mo_19 (MO)                  (None, 2, 100, 100)       10000
#
#  angular_spectrum_23 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  faraday_rotation_by_stokes_  (None, 100, 100)         0
#  3 (FaradayRotationByStokes)
#
#  mnist_detector_3 (MNISTDete  (None, 10)               0
#  ctor)
#
#  softmax_3 (Softmax)         (None, 10)                0
#
# =================================================================
# Total params: 50,000
# Trainable params: 50,000
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.6357 - accuracy: 0.5654
# Epoch 1: saving model to checkpoint/20230110/angle/2/cp-0001.ckpt
# 860/860 [==============================] - 53s 57ms/step - loss: 1.6354 - accuracy: 0.5655 - val_loss: 1.2373 - val_accuracy: 0.6934
# Epoch 2/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.1753 - accuracy: 0.6809
# Epoch 2: saving model to checkpoint/20230110/angle/2/cp-0002.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 1.1752 - accuracy: 0.6809 - val_loss: 0.9987 - val_accuracy: 0.7546
# Epoch 3/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.0203 - accuracy: 0.7261
# Epoch 3: saving model to checkpoint/20230110/angle/2/cp-0003.ckpt
# 860/860 [==============================] - 49s 56ms/step - loss: 1.0202 - accuracy: 0.7262 - val_loss: 0.8887 - val_accuracy: 0.7838
# Epoch 4/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.9389 - accuracy: 0.7509
# Epoch 4: saving model to checkpoint/20230110/angle/2/cp-0004.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.9389 - accuracy: 0.7509 - val_loss: 0.8244 - val_accuracy: 0.8032
# Epoch 5/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.8888 - accuracy: 0.7669
# Epoch 5: saving model to checkpoint/20230110/angle/2/cp-0005.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.8887 - accuracy: 0.7669 - val_loss: 0.7820 - val_accuracy: 0.8134
# Epoch 6/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.8551 - accuracy: 0.7771
# Epoch 6: saving model to checkpoint/20230110/angle/2/cp-0006.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.8552 - accuracy: 0.7771 - val_loss: 0.7544 - val_accuracy: 0.8208
# Epoch 7/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.8315 - accuracy: 0.7835
# Epoch 7: saving model to checkpoint/20230110/angle/2/cp-0007.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.8315 - accuracy: 0.7836 - val_loss: 0.7347 - val_accuracy: 0.8282
# Epoch 8/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.8139 - accuracy: 0.7891
# Epoch 8: saving model to checkpoint/20230110/angle/2/cp-0008.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.8140 - accuracy: 0.7891 - val_loss: 0.7191 - val_accuracy: 0.8330
# Epoch 9/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.8006 - accuracy: 0.7928
# Epoch 9: saving model to checkpoint/20230110/angle/2/cp-0009.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.8007 - accuracy: 0.7928 - val_loss: 0.7069 - val_accuracy: 0.8354
# Epoch 10/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7906 - accuracy: 0.7960
# Epoch 10: saving model to checkpoint/20230110/angle/2/cp-0010.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.7906 - accuracy: 0.7960 - val_loss: 0.6983 - val_accuracy: 0.8396
# Epoch 11/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7823 - accuracy: 0.7983
# Epoch 11: saving model to checkpoint/20230110/angle/2/cp-0011.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.7823 - accuracy: 0.7983 - val_loss: 0.6908 - val_accuracy: 0.8396
# Epoch 12/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7755 - accuracy: 0.8006
# Epoch 12: saving model to checkpoint/20230110/angle/2/cp-0012.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.7756 - accuracy: 0.8006 - val_loss: 0.6857 - val_accuracy: 0.8434
# Epoch 13/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7700 - accuracy: 0.8027
# Epoch 13: saving model to checkpoint/20230110/angle/2/cp-0013.ckpt
# 860/860 [==============================] - 49s 56ms/step - loss: 0.7701 - accuracy: 0.8026 - val_loss: 0.6808 - val_accuracy: 0.8438
# Epoch 14/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7653 - accuracy: 0.8034
# Epoch 14: saving model to checkpoint/20230110/angle/2/cp-0014.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.7653 - accuracy: 0.8034 - val_loss: 0.6769 - val_accuracy: 0.8450
# Epoch 15/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7613 - accuracy: 0.8059
# Epoch 15: saving model to checkpoint/20230110/angle/2/cp-0015.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.7614 - accuracy: 0.8059 - val_loss: 0.6737 - val_accuracy: 0.8440
# Epoch 16/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7582 - accuracy: 0.8060
# Epoch 16: saving model to checkpoint/20230110/angle/2/cp-0016.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.7582 - accuracy: 0.8061 - val_loss: 0.6701 - val_accuracy: 0.8460
# Epoch 17/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7553 - accuracy: 0.8073
# Epoch 17: saving model to checkpoint/20230110/angle/2/cp-0017.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.7553 - accuracy: 0.8073 - val_loss: 0.6676 - val_accuracy: 0.8476
# Epoch 18/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7529 - accuracy: 0.8079
# Epoch 18: saving model to checkpoint/20230110/angle/2/cp-0018.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.7529 - accuracy: 0.8079 - val_loss: 0.6651 - val_accuracy: 0.8478
# Epoch 19/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7508 - accuracy: 0.8087
# Epoch 19: saving model to checkpoint/20230110/angle/2/cp-0019.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.7508 - accuracy: 0.8087 - val_loss: 0.6629 - val_accuracy: 0.8490
# Epoch 20/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7489 - accuracy: 0.8096
# Epoch 20: saving model to checkpoint/20230110/angle/2/cp-0020.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.7489 - accuracy: 0.8097 - val_loss: 0.6618 - val_accuracy: 0.8480
# Epoch 21/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7474 - accuracy: 0.8099
# Epoch 21: saving model to checkpoint/20230110/angle/2/cp-0021.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.7474 - accuracy: 0.8099 - val_loss: 0.6605 - val_accuracy: 0.8494
# Epoch 22/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7458 - accuracy: 0.8104
# Epoch 22: saving model to checkpoint/20230110/angle/2/cp-0022.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.7458 - accuracy: 0.8104 - val_loss: 0.6589 - val_accuracy: 0.8496
# Epoch 23/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7443 - accuracy: 0.8104
# Epoch 23: saving model to checkpoint/20230110/angle/2/cp-0023.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.7443 - accuracy: 0.8104 - val_loss: 0.6571 - val_accuracy: 0.8512
# Epoch 24/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7431 - accuracy: 0.8111
# Epoch 24: saving model to checkpoint/20230110/angle/2/cp-0024.ckpt
# 860/860 [==============================] - 50s 58ms/step - loss: 0.7430 - accuracy: 0.8111 - val_loss: 0.6565 - val_accuracy: 0.8508
# Epoch 25/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7419 - accuracy: 0.8117
# Epoch 25: saving model to checkpoint/20230110/angle/2/cp-0025.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.7420 - accuracy: 0.8117 - val_loss: 0.6551 - val_accuracy: 0.8508
# Epoch 26/50
# ...
# Epoch 42: saving model to checkpoint/20230110/angle/2/cp-0042.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.7370 - accuracy: 0.8131 - val_loss: 0.6509 - val_accuracy: 0.8522
# Epoch 43/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7370 - accuracy: 0.8132
# Epoch 43: saving model to checkpoint/20230110/angle/2/cp-0043.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.7370 - accuracy: 0.8132 - val_loss: 0.6509 - val_accuracy: 0.8524
# Epoch 44/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7370 - accuracy: 0.8132
# Epoch 44: saving model to checkpoint/20230110/angle/2/cp-0044.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.7370 - accuracy: 0.8132 - val_loss: 0.6508 - val_accuracy: 0.8522
# Epoch 45/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7369 - accuracy: 0.8133
# Epoch 45: saving model to checkpoint/20230110/angle/2/cp-0045.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 0.7370 - accuracy: 0.8132 - val_loss: 0.6508 - val_accuracy: 0.8526
# Epoch 46/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7369 - accuracy: 0.8132
# Epoch 46: saving model to checkpoint/20230110/angle/2/cp-0046.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.7369 - accuracy: 0.8132 - val_loss: 0.6507 - val_accuracy: 0.8526
# Epoch 47/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7368 - accuracy: 0.8133
# Epoch 47: saving model to checkpoint/20230110/angle/2/cp-0047.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.7369 - accuracy: 0.8133 - val_loss: 0.6506 - val_accuracy: 0.8528
# Epoch 48/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7368 - accuracy: 0.8134
# Epoch 48: saving model to checkpoint/20230110/angle/2/cp-0048.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.7368 - accuracy: 0.8134 - val_loss: 0.6505 - val_accuracy: 0.8530
# Epoch 49/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7367 - accuracy: 0.8133
# Epoch 49: saving model to checkpoint/20230110/angle/2/cp-0049.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.7367 - accuracy: 0.8133 - val_loss: 0.6504 - val_accuracy: 0.8534
# Epoch 50/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.7365 - accuracy: 0.8134
# Epoch 50: saving model to checkpoint/20230110/angle/2/cp-0050.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 0.7366 - accuracy: 0.8133 - val_loss: 0.6503 - val_accuracy: 0.8528
# WARNING:absl:Found untraced functions such as get_limited_eta, get_limited_theta, get_limited_eta, get_limited_theta, get_limited_eta while saving (showing 5 of 11). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_model/20230110/angle/2/assets
# INFO:tensorflow:Assets written to: trained_model/20230110/angle/2/assets
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 28, 28)]          0
#
#  image_resizing_4 (ImageResi  (None, 100, 100)         0
#  zing)
#
#  intensity_to_electric_field  (None, 2, 100, 100)      0
#  _4 (IntensityToElectricFiel
#  d)
#
#  angular_spectrum_24 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  mo_20 (MO)                  (None, 2, 100, 100)       10000
#
#  angular_spectrum_25 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  mo_21 (MO)                  (None, 2, 100, 100)       10000
#
#  angular_spectrum_26 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  mo_22 (MO)                  (None, 2, 100, 100)       10000
#
#  angular_spectrum_27 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  mo_23 (MO)                  (None, 2, 100, 100)       10000
#
#  angular_spectrum_28 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  mo_24 (MO)                  (None, 2, 100, 100)       10000
#
#  angular_spectrum_29 (Angula  (None, 2, 100, 100)      0
#  rSpectrum)
#
#  faraday_rotation_by_stokes_  (None, 100, 100)         0
#  4 (FaradayRotationByStokes)
#
#  mnist_detector_4 (MNISTDete  (None, 10)               0
#  ctor)
#
#  softmax_4 (Softmax)         (None, 10)                0
#
# =================================================================
# Total params: 50,000
# Trainable params: 50,000
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.9190 - accuracy: 0.5045
# Epoch 1: saving model to checkpoint/20230110/angle/3/cp-0001.ckpt
# 860/860 [==============================] - 53s 57ms/step - loss: 1.9188 - accuracy: 0.5045 - val_loss: 1.6264 - val_accuracy: 0.6044
# Epoch 2/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.5446 - accuracy: 0.5946
# Epoch 2: saving model to checkpoint/20230110/angle/3/cp-0002.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 1.5445 - accuracy: 0.5946 - val_loss: 1.3937 - val_accuracy: 0.6548
# Epoch 3/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.3948 - accuracy: 0.6279
# Epoch 3: saving model to checkpoint/20230110/angle/3/cp-0003.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 1.3947 - accuracy: 0.6279 - val_loss: 1.2864 - val_accuracy: 0.6794
# Epoch 4/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.3207 - accuracy: 0.6483
# Epoch 4: saving model to checkpoint/20230110/angle/3/cp-0004.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 1.3208 - accuracy: 0.6483 - val_loss: 1.2293 - val_accuracy: 0.7020
# Epoch 5/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2803 - accuracy: 0.6612
# Epoch 5: saving model to checkpoint/20230110/angle/3/cp-0005.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 1.2803 - accuracy: 0.6611 - val_loss: 1.1979 - val_accuracy: 0.7088
# Epoch 6/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2564 - accuracy: 0.6683
# Epoch 6: saving model to checkpoint/20230110/angle/3/cp-0006.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 1.2565 - accuracy: 0.6682 - val_loss: 1.1788 - val_accuracy: 0.7198
# Epoch 7/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2418 - accuracy: 0.6747
# Epoch 7: saving model to checkpoint/20230110/angle/3/cp-0007.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 1.2417 - accuracy: 0.6748 - val_loss: 1.1663 - val_accuracy: 0.7220
# Epoch 8/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2317 - accuracy: 0.6793
# Epoch 8: saving model to checkpoint/20230110/angle/3/cp-0008.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 1.2318 - accuracy: 0.6792 - val_loss: 1.1578 - val_accuracy: 0.7250
# Epoch 9/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2248 - accuracy: 0.6829
# Epoch 9: saving model to checkpoint/20230110/angle/3/cp-0009.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 1.2248 - accuracy: 0.6829 - val_loss: 1.1517 - val_accuracy: 0.7270
# Epoch 10/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2198 - accuracy: 0.6850
# Epoch 10: saving model to checkpoint/20230110/angle/3/cp-0010.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 1.2198 - accuracy: 0.6850 - val_loss: 1.1474 - val_accuracy: 0.7290
# Epoch 11/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2160 - accuracy: 0.6868
# Epoch 11: saving model to checkpoint/20230110/angle/3/cp-0011.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 1.2160 - accuracy: 0.6868 - val_loss: 1.1438 - val_accuracy: 0.7326
# Epoch 12/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2131 - accuracy: 0.6882
# Epoch 12: saving model to checkpoint/20230110/angle/3/cp-0012.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 1.2132 - accuracy: 0.6882 - val_loss: 1.1412 - val_accuracy: 0.7332
# Epoch 13/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2107 - accuracy: 0.6898
# Epoch 13: saving model to checkpoint/20230110/angle/3/cp-0013.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 1.2108 - accuracy: 0.6897 - val_loss: 1.1394 - val_accuracy: 0.7336
# Epoch 14/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2090 - accuracy: 0.6910
# Epoch 14: saving model to checkpoint/20230110/angle/3/cp-0014.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 1.2090 - accuracy: 0.6910 - val_loss: 1.1376 - val_accuracy: 0.7346
# Epoch 15/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2073 - accuracy: 0.6914
# Epoch 15: saving model to checkpoint/20230110/angle/3/cp-0015.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 1.2074 - accuracy: 0.6913 - val_loss: 1.1365 - val_accuracy: 0.7346
# Epoch 16/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2063 - accuracy: 0.6914
# Epoch 16: saving model to checkpoint/20230110/angle/3/cp-0016.ckpt
# 860/860 [==============================] - 49s 56ms/step - loss: 1.2062 - accuracy: 0.6915 - val_loss: 1.1351 - val_accuracy: 0.7366
# Epoch 17/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2052 - accuracy: 0.6926
# Epoch 17: saving model to checkpoint/20230110/angle/3/cp-0017.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 1.2052 - accuracy: 0.6926 - val_loss: 1.1342 - val_accuracy: 0.7368
# Epoch 18/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2042 - accuracy: 0.6927
# Epoch 18: saving model to checkpoint/20230110/angle/3/cp-0018.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 1.2043 - accuracy: 0.6927 - val_loss: 1.1335 - val_accuracy: 0.7368
# Epoch 19/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2034 - accuracy: 0.6934
# Epoch 19: saving model to checkpoint/20230110/angle/3/cp-0019.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 1.2034 - accuracy: 0.6934 - val_loss: 1.1329 - val_accuracy: 0.7386
# Epoch 20/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2030 - accuracy: 0.6939
# Epoch 20: saving model to checkpoint/20230110/angle/3/cp-0020.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 1.2029 - accuracy: 0.6940 - val_loss: 1.1322 - val_accuracy: 0.7394
# Epoch 21/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2023 - accuracy: 0.6939
# Epoch 21: saving model to checkpoint/20230110/angle/3/cp-0021.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 1.2023 - accuracy: 0.6939 - val_loss: 1.1316 - val_accuracy: 0.7398
# Epoch 22/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2019 - accuracy: 0.6941
# Epoch 22: saving model to checkpoint/20230110/angle/3/cp-0022.ckpt
# 860/860 [==============================] - 60s 69ms/step - loss: 1.2018 - accuracy: 0.6941 - val_loss: 1.1314 - val_accuracy: 0.7398
# Epoch 23/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2014 - accuracy: 0.6952
# Epoch 23: saving model to checkpoint/20230110/angle/3/cp-0023.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 1.2014 - accuracy: 0.6952 - val_loss: 1.1310 - val_accuracy: 0.7396
# Epoch 24/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2010 - accuracy: 0.6948
# Epoch 24: saving model to checkpoint/20230110/angle/3/cp-0024.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 1.2010 - accuracy: 0.6948 - val_loss: 1.1306 - val_accuracy: 0.7400
# Epoch 25/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2006 - accuracy: 0.6956
# Epoch 25: saving model to checkpoint/20230110/angle/3/cp-0025.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 1.2007 - accuracy: 0.6956 - val_loss: 1.1303 - val_accuracy: 0.7394
# Epoch 26/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2005 - accuracy: 0.6951
# Epoch 26: saving model to checkpoint/20230110/angle/3/cp-0026.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 1.2004 - accuracy: 0.6951 - val_loss: 1.1300 - val_accuracy: 0.7406
# Epoch 27/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2002 - accuracy: 0.6958
# Epoch 27: saving model to checkpoint/20230110/angle/3/cp-0027.ckpt
# 860/860 [==============================] - 49s 57ms/step - loss: 1.2002 - accuracy: 0.6958 - val_loss: 1.1297 - val_accuracy: 0.7410
# Epoch 28/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2000 - accuracy: 0.6962
# Epoch 28: saving model to checkpoint/20230110/angle/3/cp-0028.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 1.1999 - accuracy: 0.6962 - val_loss: 1.1295 - val_accuracy: 0.7408
# Epoch 29/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.1998 - accuracy: 0.6967
# Epoch 29: saving model to checkpoint/20230110/angle/3/cp-0029.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 1.1997 - accuracy: 0.6968 - val_loss: 1.1293 - val_accuracy: 0.7410
# Epoch 30/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.1995 - accuracy: 0.6965
# Epoch 30: saving model to checkpoint/20230110/angle/3/cp-0030.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 1.1995 - accuracy: 0.6965 - val_loss: 1.1292 - val_accuracy: 0.7410
# Epoch 31/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.1993 - accuracy: 0.6967
# Epoch 31: saving model to checkpoint/20230110/angle/3/cp-0031.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 1.1993 - accuracy: 0.6967 - val_loss: 1.1290 - val_accuracy: 0.7416
# Epoch 32/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.1992 - accuracy: 0.6968
# Epoch 32: saving model to checkpoint/20230110/angle/3/cp-0032.ckpt
# 860/860 [==============================] - 48s 56ms/step - loss: 1.1992 - accuracy: 0.6968 - val_loss: 1.1288 - val_accuracy: 0.7412
# Epoch 33/50
# 267/860 [========>.....................] - ETA: 31s - loss: 1.2017 - accuracy: 0.6941
