# %%
import sys

sys.path.append('/notebooks/MOD2NN')
import os
import json

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

from CNN.module.lib.layers import *
from Faraday.two_dim.module.lib.layers import *

from Faraday.two_dim import matplotlib_style

matplotlib_style.paper()

tf.random.set_seed(1)

print("TensorFlow:", tf.__version__)
print("Python:", sys.version)

plt.rcParams['font.size'] = 18
# Out:
# TensorFlow: 2.9.1
# Python: 3.9.13 (main, May 23 2022, 22:01:06)
# [GCC 9.4.0]

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = np.sqrt(x_train.astype("float32") / 255.0)
x_test = np.sqrt(x_test.astype("float32") / 255.0)

y_train = y_train.astype("float32")
y_test = y_test.astype("float32")

# Reserve 10,000 samples for validation
x_val = x_train[-5000:]
y_val = y_train[-5000:]
x_train = x_train[:-5000]
y_train = y_train[:-5000]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
#@title デフォルトのタイトル テキスト
wavelength = 633.0e-9  #@param {type:"number"}
d = 1.0e-6  #@param {type:"number"}
n = 1.5  #@param {type:"number"}
z = 0.7e-3  #@param {type:"number"}

# %%
def create_model(**kwargs):
    shape = (100, 100)
    theta = kwargs["theta"]
    eta = 0.
    tf.random.set_seed(kwargs["seed"])
    inputs = tf.keras.Input((28, 28))
    x = ImageResizing(shape)(inputs)
    x = IntensityToElectricField(shape)(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=z, d=d, n=n, method='expand')(x)
    x = BinarizedMO(shape, theta=theta, eta=eta, beta=5.)(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=z, d=d, n=n, method='expand')(x)
    x = BinarizedMO(shape, theta=theta, eta=eta, beta=5.)(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=z, d=d, n=n, method='expand')(x)
    x = BinarizedMO(shape, theta=theta, eta=eta, beta=5.)(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=z, d=d, n=n, method='expand')(x)
    x = BinarizedMO(shape, theta=theta, eta=eta, beta=5.)(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=z, d=d, n=n, method='expand')(x)
    x = BinarizedMO(shape, theta=theta, eta=eta, beta=5.)(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=z, d=d, n=n, method='expand')(x)
    x = FaradayRotationByStokes(shape)(x)
    x = MNISTDetector(shape)(x)
    x = tf.keras.layers.Softmax()(x)
    model = tf.keras.Model(inputs, x)
    return model

# %%
def train(seed, theta, num):
    model_name = "20230119/angle"
    checkpoint_path = "checkpoint/" + model_name + "/cp-{epoch:04d}.ckpt"
    checkpoint_dir = os.path.dirname(checkpoint_path)
    path = "trained_model/" + model_name

    model = create_model(seed=seed, theta=theta)
    model.summary()
    model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss=tf.keras.losses.sparse_categorical_crossentropy,  # category: sparse_categorical_crossentropy
                  metrics=["accuracy"]
                  )

    epochs = 50
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='loss',
        min_delta=0.0002,
        patience=2,
    )

    # チェックポイントコールバックを作る
    cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                     save_weights_only=True,
                                                     verbose=1)

    logdir = os.path.join("logs", model_name)
    tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

    result = model.fit(x_train,
                       y_train,
                       batch_size=64,
                       epochs=epochs,
                       validation_data=(x_val, y_val),
                       callbacks=[cp_callback, tensorboard_callback]
                       )

    model.save(path)

    df = pd.DataFrame(result.history)
    df.to_csv(path + "/history.csv")

    with open(path + "/config.json", 'w') as f:
        json.dump(model.get_config(), f, indent=4)

# %%
train(seed=1, theta=np.pi/100, num=1)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28)]          0
#
#  image_resizing (ImageResizi  (None, 100, 100)         0
#  ng)
#
#  intensity_to_electric_field  (None, 2, 100, 100)      0
#   (IntensityToElectricField)
#
#  angular_spectrum (AngularSp  (None, 2, 100, 100)      0
#  ectrum)
#
#  binarized_mo (BinarizedMO)  (None, 2, 100, 100)       10000
#
#  angular_spectrum_1 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  binarized_mo_1 (BinarizedMO  (None, 2, 100, 100)      10000
#  )
#
#  angular_spectrum_2 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  binarized_mo_2 (BinarizedMO  (None, 2, 100, 100)      10000
#  )
#
#  angular_spectrum_3 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  binarized_mo_3 (BinarizedMO  (None, 2, 100, 100)      10000
#  )
#
#  angular_spectrum_4 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  binarized_mo_4 (BinarizedMO  (None, 2, 100, 100)      10000
#  )
#
#  angular_spectrum_5 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  faraday_rotation_by_stokes   (None, 100, 100)         0
#  (FaradayRotationByStokes)
#
#  mnist_detector (MNISTDetect  (None, 10)               0
#  or)
#
#  softmax (Softmax)           (None, 10)                0
#
# =================================================================
# Total params: 50,000
# Trainable params: 50,000
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.9058 - accuracy: 0.7442
# Epoch 1: saving model to checkpoint/20230119/angle/cp-0001.ckpt
# 860/860 [==============================] - 89s 100ms/step - loss: 0.9057 - accuracy: 0.7442 - val_loss: 0.5495 - val_accuracy: 0.8644
# Epoch 2/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.6079 - accuracy: 0.8346
# Epoch 2: saving model to checkpoint/20230119/angle/cp-0002.ckpt
# 860/860 [==============================] - 85s 99ms/step - loss: 0.6078 - accuracy: 0.8346 - val_loss: 0.4864 - val_accuracy: 0.8786
# Epoch 3/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5604 - accuracy: 0.8478
# Epoch 3: saving model to checkpoint/20230119/angle/cp-0003.ckpt
# 860/860 [==============================] - 86s 100ms/step - loss: 0.5604 - accuracy: 0.8478 - val_loss: 0.4614 - val_accuracy: 0.8824
# Epoch 4/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5399 - accuracy: 0.8535
# Epoch 4: saving model to checkpoint/20230119/angle/cp-0004.ckpt
# 860/860 [==============================] - 83s 96ms/step - loss: 0.5398 - accuracy: 0.8535 - val_loss: 0.4474 - val_accuracy: 0.8864
# Epoch 5/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5288 - accuracy: 0.8568
# Epoch 5: saving model to checkpoint/20230119/angle/cp-0005.ckpt
# 860/860 [==============================] - 83s 96ms/step - loss: 0.5287 - accuracy: 0.8568 - val_loss: 0.4396 - val_accuracy: 0.8908
# Epoch 6/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5208 - accuracy: 0.8595
# Epoch 6: saving model to checkpoint/20230119/angle/cp-0006.ckpt
# 860/860 [==============================] - 93s 108ms/step - loss: 0.5209 - accuracy: 0.8594 - val_loss: 0.4369 - val_accuracy: 0.8886
# Epoch 7/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5160 - accuracy: 0.8599
# Epoch 7: saving model to checkpoint/20230119/angle/cp-0007.ckpt
# 860/860 [==============================] - 83s 96ms/step - loss: 0.5159 - accuracy: 0.8599 - val_loss: 0.4336 - val_accuracy: 0.8914
# Epoch 8/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5132 - accuracy: 0.8619
# Epoch 8: saving model to checkpoint/20230119/angle/cp-0008.ckpt
# 860/860 [==============================] - 90s 105ms/step - loss: 0.5132 - accuracy: 0.8620 - val_loss: 0.4377 - val_accuracy: 0.8908
# Epoch 9/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5106 - accuracy: 0.8623
# Epoch 9: saving model to checkpoint/20230119/angle/cp-0009.ckpt
# 860/860 [==============================] - 83s 96ms/step - loss: 0.5109 - accuracy: 0.8623 - val_loss: 0.4285 - val_accuracy: 0.8928
# Epoch 10/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5081 - accuracy: 0.8628
# Epoch 10: saving model to checkpoint/20230119/angle/cp-0010.ckpt
# 860/860 [==============================] - 87s 102ms/step - loss: 0.5080 - accuracy: 0.8628 - val_loss: 0.4305 - val_accuracy: 0.8922
# Epoch 11/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5060 - accuracy: 0.8622
# Epoch 11: saving model to checkpoint/20230119/angle/cp-0011.ckpt
# 860/860 [==============================] - 85s 98ms/step - loss: 0.5060 - accuracy: 0.8622 - val_loss: 0.4272 - val_accuracy: 0.8942
# Epoch 12/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5042 - accuracy: 0.8641
# Epoch 12: saving model to checkpoint/20230119/angle/cp-0012.ckpt
# 860/860 [==============================] - 86s 100ms/step - loss: 0.5044 - accuracy: 0.8641 - val_loss: 0.4276 - val_accuracy: 0.8928
# Epoch 13/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5031 - accuracy: 0.8652
# Epoch 13: saving model to checkpoint/20230119/angle/cp-0013.ckpt
# 860/860 [==============================] - 111s 129ms/step - loss: 0.5031 - accuracy: 0.8651 - val_loss: 0.4244 - val_accuracy: 0.8946
# Epoch 14/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5033 - accuracy: 0.8647
# Epoch 14: saving model to checkpoint/20230119/angle/cp-0014.ckpt
# 860/860 [==============================] - 87s 102ms/step - loss: 0.5033 - accuracy: 0.8647 - val_loss: 0.4210 - val_accuracy: 0.8982
# Epoch 15/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5013 - accuracy: 0.8660
# Epoch 15: saving model to checkpoint/20230119/angle/cp-0015.ckpt
# 860/860 [==============================] - 86s 100ms/step - loss: 0.5014 - accuracy: 0.8660 - val_loss: 0.4222 - val_accuracy: 0.8938
# Epoch 16/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4999 - accuracy: 0.8659
# Epoch 16: saving model to checkpoint/20230119/angle/cp-0016.ckpt
# 860/860 [==============================] - 109s 127ms/step - loss: 0.4999 - accuracy: 0.8659 - val_loss: 0.4192 - val_accuracy: 0.8946
# Epoch 17/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.5003 - accuracy: 0.8657
# Epoch 17: saving model to checkpoint/20230119/angle/cp-0017.ckpt
# 860/860 [==============================] - 103s 120ms/step - loss: 0.5002 - accuracy: 0.8657 - val_loss: 0.4215 - val_accuracy: 0.8980
# Epoch 18/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4998 - accuracy: 0.8658
# Epoch 18: saving model to checkpoint/20230119/angle/cp-0018.ckpt
# 860/860 [==============================] - 84s 97ms/step - loss: 0.4998 - accuracy: 0.8658 - val_loss: 0.4179 - val_accuracy: 0.8992
# Epoch 19/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4988 - accuracy: 0.8668
# Epoch 19: saving model to checkpoint/20230119/angle/cp-0019.ckpt
# 860/860 [==============================] - 83s 96ms/step - loss: 0.4988 - accuracy: 0.8668 - val_loss: 0.4205 - val_accuracy: 0.8962
# Epoch 20/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4982 - accuracy: 0.8666
# Epoch 20: saving model to checkpoint/20230119/angle/cp-0020.ckpt
# 860/860 [==============================] - 83s 96ms/step - loss: 0.4981 - accuracy: 0.8666 - val_loss: 0.4182 - val_accuracy: 0.8962
# Epoch 21/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4982 - accuracy: 0.8668
# Epoch 21: saving model to checkpoint/20230119/angle/cp-0021.ckpt
# 860/860 [==============================] - 90s 104ms/step - loss: 0.4981 - accuracy: 0.8668 - val_loss: 0.4181 - val_accuracy: 0.8978
# Epoch 22/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4973 - accuracy: 0.8674
# Epoch 22: saving model to checkpoint/20230119/angle/cp-0022.ckpt
# 860/860 [==============================] - 89s 104ms/step - loss: 0.4972 - accuracy: 0.8674 - val_loss: 0.4153 - val_accuracy: 0.8954
# Epoch 23/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4970 - accuracy: 0.8671
# Epoch 23: saving model to checkpoint/20230119/angle/cp-0023.ckpt
# 860/860 [==============================] - 91s 106ms/step - loss: 0.4970 - accuracy: 0.8671 - val_loss: 0.4167 - val_accuracy: 0.8980
# Epoch 24/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4970 - accuracy: 0.8672
# Epoch 24: saving model to checkpoint/20230119/angle/cp-0024.ckpt
# 860/860 [==============================] - 94s 110ms/step - loss: 0.4969 - accuracy: 0.8672 - val_loss: 0.4171 - val_accuracy: 0.8994
# Epoch 25/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4968 - accuracy: 0.8675
# Epoch 25: saving model to checkpoint/20230119/angle/cp-0025.ckpt
# 860/860 [==============================] - 84s 98ms/step - loss: 0.4969 - accuracy: 0.8675 - val_loss: 0.4180 - val_accuracy: 0.8978
# Epoch 26/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4966 - accuracy: 0.8673
# Epoch 26: saving model to checkpoint/20230119/angle/cp-0026.ckpt
# 860/860 [==============================] - 97s 112ms/step - loss: 0.4966 - accuracy: 0.8673 - val_loss: 0.4169 - val_accuracy: 0.8958
# Epoch 27/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4966 - accuracy: 0.8672
# Epoch 27: saving model to checkpoint/20230119/angle/cp-0027.ckpt
# 860/860 [==============================] - 83s 96ms/step - loss: 0.4965 - accuracy: 0.8672 - val_loss: 0.4163 - val_accuracy: 0.8972
# Epoch 28/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4953 - accuracy: 0.8675
# Epoch 28: saving model to checkpoint/20230119/angle/cp-0028.ckpt
# 860/860 [==============================] - 88s 103ms/step - loss: 0.4953 - accuracy: 0.8675 - val_loss: 0.4172 - val_accuracy: 0.9014
# Epoch 29/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4966 - accuracy: 0.8669
# Epoch 29: saving model to checkpoint/20230119/angle/cp-0029.ckpt
# 860/860 [==============================] - 84s 98ms/step - loss: 0.4966 - accuracy: 0.8669 - val_loss: 0.4164 - val_accuracy: 0.8976
# Epoch 30/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4955 - accuracy: 0.8677
# Epoch 30: saving model to checkpoint/20230119/angle/cp-0030.ckpt
# 860/860 [==============================] - 83s 96ms/step - loss: 0.4955 - accuracy: 0.8677 - val_loss: 0.4171 - val_accuracy: 0.8970
# Epoch 31/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4955 - accuracy: 0.8678
# Epoch 31: saving model to checkpoint/20230119/angle/cp-0031.ckpt
# 860/860 [==============================] - 89s 104ms/step - loss: 0.4955 - accuracy: 0.8677 - val_loss: 0.4136 - val_accuracy: 0.8996
# Epoch 32/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4951 - accuracy: 0.8678
# Epoch 32: saving model to checkpoint/20230119/angle/cp-0032.ckpt
# 860/860 [==============================] - 83s 96ms/step - loss: 0.4951 - accuracy: 0.8678 - val_loss: 0.4163 - val_accuracy: 0.8966
# Epoch 33/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4948 - accuracy: 0.8681
# Epoch 33: saving model to checkpoint/20230119/angle/cp-0033.ckpt
# 860/860 [==============================] - 86s 100ms/step - loss: 0.4948 - accuracy: 0.8681 - val_loss: 0.4146 - val_accuracy: 0.8992
# Epoch 34/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4950 - accuracy: 0.8679
# Epoch 34: saving model to checkpoint/20230119/angle/cp-0034.ckpt
# 860/860 [==============================] - 96s 111ms/step - loss: 0.4950 - accuracy: 0.8679 - val_loss: 0.4167 - val_accuracy: 0.9012
# Epoch 35/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4952 - accuracy: 0.8686
# Epoch 35: saving model to checkpoint/20230119/angle/cp-0035.ckpt
# 860/860 [==============================] - 89s 104ms/step - loss: 0.4952 - accuracy: 0.8686 - val_loss: 0.4155 - val_accuracy: 0.8982
# Epoch 36/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4948 - accuracy: 0.8672
# Epoch 36: saving model to checkpoint/20230119/angle/cp-0036.ckpt
# 860/860 [==============================] - 91s 106ms/step - loss: 0.4947 - accuracy: 0.8672 - val_loss: 0.4158 - val_accuracy: 0.8980
# Epoch 37/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4950 - accuracy: 0.8683
# Epoch 37: saving model to checkpoint/20230119/angle/cp-0037.ckpt
# 860/860 [==============================] - 94s 110ms/step - loss: 0.4951 - accuracy: 0.8683 - val_loss: 0.4190 - val_accuracy: 0.8966
# Epoch 38/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4946 - accuracy: 0.8683
# Epoch 38: saving model to checkpoint/20230119/angle/cp-0038.ckpt
# 860/860 [==============================] - 90s 105ms/step - loss: 0.4946 - accuracy: 0.8683 - val_loss: 0.4179 - val_accuracy: 0.8986
# Epoch 39/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4946 - accuracy: 0.8678
# Epoch 39: saving model to checkpoint/20230119/angle/cp-0039.ckpt
# 860/860 [==============================] - 86s 99ms/step - loss: 0.4945 - accuracy: 0.8679 - val_loss: 0.4173 - val_accuracy: 0.8970
# Epoch 40/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4945 - accuracy: 0.8686
# Epoch 40: saving model to checkpoint/20230119/angle/cp-0040.ckpt
# 860/860 [==============================] - 83s 96ms/step - loss: 0.4945 - accuracy: 0.8686 - val_loss: 0.4154 - val_accuracy: 0.8982
# Epoch 41/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4944 - accuracy: 0.8675
# Epoch 41: saving model to checkpoint/20230119/angle/cp-0041.ckpt
# 860/860 [==============================] - 83s 96ms/step - loss: 0.4943 - accuracy: 0.8675 - val_loss: 0.4177 - val_accuracy: 0.8968
# Epoch 42/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4940 - accuracy: 0.8688
# Epoch 42: saving model to checkpoint/20230119/angle/cp-0042.ckpt
# 860/860 [==============================] - 91s 106ms/step - loss: 0.4939 - accuracy: 0.8688 - val_loss: 0.4127 - val_accuracy: 0.9002
# Epoch 43/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4943 - accuracy: 0.8688
# Epoch 43: saving model to checkpoint/20230119/angle/cp-0043.ckpt
# 860/860 [==============================] - 87s 101ms/step - loss: 0.4943 - accuracy: 0.8688 - val_loss: 0.4138 - val_accuracy: 0.8948
# Epoch 44/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4942 - accuracy: 0.8676
# Epoch 44: saving model to checkpoint/20230119/angle/cp-0044.ckpt
# 860/860 [==============================] - 84s 97ms/step - loss: 0.4942 - accuracy: 0.8676 - val_loss: 0.4160 - val_accuracy: 0.9008
# Epoch 45/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4935 - accuracy: 0.8694
# Epoch 45: saving model to checkpoint/20230119/angle/cp-0045.ckpt
# 860/860 [==============================] - 84s 97ms/step - loss: 0.4935 - accuracy: 0.8693 - val_loss: 0.4149 - val_accuracy: 0.8978
# Epoch 46/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4937 - accuracy: 0.8689
# Epoch 46: saving model to checkpoint/20230119/angle/cp-0046.ckpt
# 860/860 [==============================] - 91s 106ms/step - loss: 0.4937 - accuracy: 0.8689 - val_loss: 0.4131 - val_accuracy: 0.8968
# Epoch 47/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4941 - accuracy: 0.8681
# Epoch 47: saving model to checkpoint/20230119/angle/cp-0047.ckpt
# 860/860 [==============================] - 85s 99ms/step - loss: 0.4941 - accuracy: 0.8681 - val_loss: 0.4149 - val_accuracy: 0.9002
# Epoch 48/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4940 - accuracy: 0.8681
# Epoch 48: saving model to checkpoint/20230119/angle/cp-0048.ckpt
# 860/860 [==============================] - 91s 105ms/step - loss: 0.4940 - accuracy: 0.8681 - val_loss: 0.4150 - val_accuracy: 0.8980
# Epoch 49/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4934 - accuracy: 0.8687
# Epoch 49: saving model to checkpoint/20230119/angle/cp-0049.ckpt
# 860/860 [==============================] - 90s 105ms/step - loss: 0.4935 - accuracy: 0.8687 - val_loss: 0.4147 - val_accuracy: 0.8988
# Epoch 50/50
# 859/860 [============================>.] - ETA: 0s - loss: 0.4940 - accuracy: 0.8687
# Epoch 50: saving model to checkpoint/20230119/angle/cp-0050.ckpt
# 860/860 [==============================] - 90s 104ms/step - loss: 0.4940 - accuracy: 0.8686 - val_loss: 0.4175 - val_accuracy: 0.8978
# WARNING:absl:Found untraced functions such as get_b_kernel, get_limited_complex_faraday, get_limited_eta, get_limited_theta, get_b_kernel while saving (showing 5 of 21). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_model/20230119/angle/assets
# INFO:tensorflow:Assets written to: trained_model/20230119/angle/assets
