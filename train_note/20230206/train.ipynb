# %% [markdown]
# # GGG基盤ガーネット再学習

# %%
import sys
sys.path.append('/notebooks/MOD2NN')

# %%
import time
import sys
import os
import json

import pandas as pd
from Faraday.two_dim.module.lib.layers import *

tf.random.set_seed(1)

print("TensorFlow:", tf.__version__)
print("Python:", sys.version)

plt.rcParams['font.size'] = 18
# Out:
# TensorFlow: 2.9.1
# Python: 3.9.13 (main, May 23 2022, 22:01:06)
# [GCC 9.4.0]

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

y_train = y_train.astype("float32")
y_test = y_test.astype("float32")

# Reserve 10,000 samples for validation
x_val = x_train[-5000:]
y_val = y_train[-5000:]
x_train = x_train[:-5000]
y_train = y_train[:-5000]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
#@title デフォルトのタイトル テキスト
wavelength = 532.0e-9 #@param {type:"number"}
d = 1.0e-6 #@param {type:"number"}

# %% [markdown]
# # 連続値

# %%
def create_model(**kwargs):
    shape = (100, 100)
    theta = -2.105 * np.pi / 180. / 2.
    eta = np.arctan(0.9785 * np.pi/100. / 2.)
    z = kwargs["z"]
    tf.random.set_seed(kwargs["seed"])
    inputs = tf.keras.Input((28, 28))
    x = ImageResizing(shape)(inputs)
    x = ImageBinarization()(x)
    x = IntensityToElectricField(shape)(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=z, d=d, n=1.0, method='expand')(x)
    x = MO(shape, limitation='sin', theta=theta, eta=eta)(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=0.5e-3, d=d, n=2.0, method='expand')(x)
    x = MO(shape, limitation='sin', theta=theta, eta=eta)(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=0.5e-3, d=d, n=1.0, method='expand')(x)
    x = FaradayRotationByStokes(shape)(x)
    x = MNISTDetector(shape)(x)
    x = tf.keras.layers.Softmax()(x)
    model = tf.keras.Model(inputs, x)
    return model

# %%
def train(seed, z):
    model_name = "20230206/z0_{:f}_seed_{:d}".format(z, seed)
    cholab_path = "/content/drive/MyDrive/D2NN/"
    checkpoint_path = "checkpoint/" + model_name + "/cp-{epoch:04d}.ckpt"
    checkpoint_dir = os.path.dirname(checkpoint_path)
    path = "trained_model/"+ model_name

    model = create_model(seed=seed, z=z)
    model.summary()
    model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss=tf.keras.losses.sparse_categorical_crossentropy,  # category: sparse_categorical_crossentropy
                  metrics=["accuracy"]
                  )

    epochs = 50
    early_stopping = tf.keras.callbacks.EarlyStopping(
            monitor='loss',
            min_delta=0.0002,
            patience=2,
        )

    # チェックポイントコールバックを作る
    cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                     save_weights_only=True,
                                                     verbose=1)

    logdir = os.path.join(cholab_path +"logs", model_name)
    tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

    result = model.fit(x_train,
                       y_train,
                       batch_size=64,
                       epochs=epochs,
                       validation_data=(x_val, y_val),
                       callbacks=[cp_callback, tensorboard_callback]
                       )

    model.save(path)

    df = pd.DataFrame(result.history)
    df.to_csv(path + "/history.csv")



    with open(path + "/config.json", 'w') as f:
        json.dump(model.get_config(), f, indent=4)

# %%
train(1, 0.5e-3)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28)]          0
#
#  image_resizing (ImageResizi  (None, 100, 100)         0
#  ng)
#
#  image_binarization (ImageBi  (None, 100, 100)         0
#  narization)
#
#  intensity_to_electric_field  (None, 2, 100, 100)      0
#   (IntensityToElectricField)
#
#  angular_spectrum (AngularSp  (None, 2, 100, 100)      0
#  ectrum)
#
#  mo (MO)                     (None, 2, 100, 100)       10000
#
#  angular_spectrum_1 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  mo_1 (MO)                   (None, 2, 100, 100)       10000
#
#  angular_spectrum_2 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  faraday_rotation_by_stokes   (None, 100, 100)         0
#  (FaradayRotationByStokes)
#
#  mnist_detector (MNISTDetect  (None, 10)               0
#  or)
#
#  softmax (Softmax)           (None, 10)                0
#
# =================================================================
# Total params: 20,000
# Trainable params: 20,000
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.9320 - accuracy: 0.4275
# Epoch 1: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0001.ckpt
# 860/860 [==============================] - 29s 29ms/step - loss: 1.9319 - accuracy: 0.4276 - val_loss: 1.6903 - val_accuracy: 0.5130
# Epoch 2/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.6372 - accuracy: 0.5131
# Epoch 2: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0002.ckpt
# 860/860 [==============================] - 24s 28ms/step - loss: 1.6371 - accuracy: 0.5132 - val_loss: 1.5173 - val_accuracy: 0.5580
# Epoch 3/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.5228 - accuracy: 0.5418
# Epoch 3: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0003.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.5228 - accuracy: 0.5418 - val_loss: 1.4302 - val_accuracy: 0.5782
# Epoch 4/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.4582 - accuracy: 0.5596
# Epoch 4: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0004.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.4581 - accuracy: 0.5596 - val_loss: 1.3732 - val_accuracy: 0.5932
# Epoch 5/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.4160 - accuracy: 0.5721
# Epoch 5: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0005.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.4159 - accuracy: 0.5721 - val_loss: 1.3371 - val_accuracy: 0.6002
# Epoch 6/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.3863 - accuracy: 0.5808
# Epoch 6: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0006.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.3864 - accuracy: 0.5808 - val_loss: 1.3096 - val_accuracy: 0.6116
# Epoch 7/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.3652 - accuracy: 0.5871
# Epoch 7: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0007.ckpt
# 860/860 [==============================] - 24s 28ms/step - loss: 1.3651 - accuracy: 0.5872 - val_loss: 1.2901 - val_accuracy: 0.6188
# Epoch 8/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.3489 - accuracy: 0.5927
# Epoch 8: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0008.ckpt
# 860/860 [==============================] - 24s 28ms/step - loss: 1.3489 - accuracy: 0.5927 - val_loss: 1.2762 - val_accuracy: 0.6234
# Epoch 9/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.3365 - accuracy: 0.5969
# Epoch 9: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0009.ckpt
# 860/860 [==============================] - 24s 28ms/step - loss: 1.3366 - accuracy: 0.5969 - val_loss: 1.2638 - val_accuracy: 0.6270
# Epoch 10/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.3271 - accuracy: 0.5996
# Epoch 10: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0010.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.3270 - accuracy: 0.5996 - val_loss: 1.2542 - val_accuracy: 0.6296
# Epoch 11/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.3192 - accuracy: 0.6018
# Epoch 11: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0011.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.3191 - accuracy: 0.6019 - val_loss: 1.2475 - val_accuracy: 0.6316
# Epoch 12/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.3128 - accuracy: 0.6043
# Epoch 12: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0012.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.3129 - accuracy: 0.6043 - val_loss: 1.2422 - val_accuracy: 0.6338
# Epoch 13/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.3076 - accuracy: 0.6058
# Epoch 13: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0013.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.3078 - accuracy: 0.6057 - val_loss: 1.2372 - val_accuracy: 0.6340
# Epoch 14/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.3034 - accuracy: 0.6074
# Epoch 14: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0014.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.3034 - accuracy: 0.6074 - val_loss: 1.2341 - val_accuracy: 0.6348
# Epoch 15/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2999 - accuracy: 0.6086
# Epoch 15: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0015.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2998 - accuracy: 0.6086 - val_loss: 1.2301 - val_accuracy: 0.6378
# Epoch 16/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2966 - accuracy: 0.6093
# Epoch 16: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0016.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2966 - accuracy: 0.6093 - val_loss: 1.2275 - val_accuracy: 0.6372
# Epoch 17/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2937 - accuracy: 0.6103
# Epoch 17: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0017.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2936 - accuracy: 0.6104 - val_loss: 1.2257 - val_accuracy: 0.6390
# Epoch 18/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2915 - accuracy: 0.6109
# Epoch 18: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0018.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2914 - accuracy: 0.6109 - val_loss: 1.2236 - val_accuracy: 0.6382
# Epoch 19/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2893 - accuracy: 0.6114
# Epoch 19: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0019.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2892 - accuracy: 0.6114 - val_loss: 1.2218 - val_accuracy: 0.6410
# Epoch 20/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2876 - accuracy: 0.6129
# Epoch 20: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0020.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2876 - accuracy: 0.6130 - val_loss: 1.2201 - val_accuracy: 0.6394
# Epoch 21/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2859 - accuracy: 0.6132
# Epoch 21: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0021.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2858 - accuracy: 0.6133 - val_loss: 1.2195 - val_accuracy: 0.6402
# Epoch 22/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2844 - accuracy: 0.6141
# Epoch 22: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0022.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2844 - accuracy: 0.6142 - val_loss: 1.2176 - val_accuracy: 0.6414
# Epoch 23/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2833 - accuracy: 0.6147
# Epoch 23: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0023.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2833 - accuracy: 0.6148 - val_loss: 1.2172 - val_accuracy: 0.6412
# Epoch 24/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2820 - accuracy: 0.6145
# Epoch 24: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0024.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2820 - accuracy: 0.6145 - val_loss: 1.2164 - val_accuracy: 0.6432
# Epoch 25/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2810 - accuracy: 0.6151
# Epoch 25: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0025.ckpt
# 860/860 [==============================] - 25s 30ms/step - loss: 1.2812 - accuracy: 0.6150 - val_loss: 1.2151 - val_accuracy: 0.6432
# Epoch 26/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2800 - accuracy: 0.6154
# Epoch 26: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0026.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2799 - accuracy: 0.6154 - val_loss: 1.2145 - val_accuracy: 0.6440
# Epoch 27/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2790 - accuracy: 0.6161
# Epoch 27: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0027.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2789 - accuracy: 0.6161 - val_loss: 1.2143 - val_accuracy: 0.6438
# Epoch 28/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2784 - accuracy: 0.6163
# Epoch 28: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0028.ckpt
# 860/860 [==============================] - 25s 30ms/step - loss: 1.2783 - accuracy: 0.6164 - val_loss: 1.2131 - val_accuracy: 0.6442
# Epoch 29/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2777 - accuracy: 0.6167
# Epoch 29: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0029.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2778 - accuracy: 0.6166 - val_loss: 1.2128 - val_accuracy: 0.6444
# Epoch 30/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2770 - accuracy: 0.6163
# Epoch 30: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0030.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2770 - accuracy: 0.6162 - val_loss: 1.2125 - val_accuracy: 0.6448
# Epoch 31/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2763 - accuracy: 0.6169
# Epoch 31: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0031.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2764 - accuracy: 0.6168 - val_loss: 1.2119 - val_accuracy: 0.6466
# Epoch 32/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2758 - accuracy: 0.6173
# Epoch 32: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0032.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2759 - accuracy: 0.6172 - val_loss: 1.2112 - val_accuracy: 0.6442
# Epoch 33/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2751 - accuracy: 0.6178
# Epoch 33: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0033.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2752 - accuracy: 0.6178 - val_loss: 1.2111 - val_accuracy: 0.6458
# Epoch 34/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2747 - accuracy: 0.6174
# Epoch 34: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0034.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2747 - accuracy: 0.6174 - val_loss: 1.2106 - val_accuracy: 0.6464
# Epoch 35/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2743 - accuracy: 0.6175
# Epoch 35: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0035.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2743 - accuracy: 0.6175 - val_loss: 1.2100 - val_accuracy: 0.6458
# Epoch 36/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2741 - accuracy: 0.6179
# Epoch 36: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0036.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2741 - accuracy: 0.6180 - val_loss: 1.2101 - val_accuracy: 0.6458
# Epoch 37/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2736 - accuracy: 0.6181
# Epoch 37: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0037.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2735 - accuracy: 0.6181 - val_loss: 1.2097 - val_accuracy: 0.6470
# Epoch 38/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2732 - accuracy: 0.6185
# Epoch 38: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0038.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2732 - accuracy: 0.6185 - val_loss: 1.2094 - val_accuracy: 0.6470
# Epoch 39/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2731 - accuracy: 0.6184
# Epoch 39: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0039.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2730 - accuracy: 0.6185 - val_loss: 1.2094 - val_accuracy: 0.6458
# Epoch 40/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2726 - accuracy: 0.6182
# Epoch 40: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0040.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2726 - accuracy: 0.6181 - val_loss: 1.2085 - val_accuracy: 0.6474
# Epoch 41/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2723 - accuracy: 0.6181
# Epoch 41: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0041.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2723 - accuracy: 0.6181 - val_loss: 1.2080 - val_accuracy: 0.6476
# Epoch 42/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2720 - accuracy: 0.6184
# Epoch 42: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0042.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2719 - accuracy: 0.6184 - val_loss: 1.2083 - val_accuracy: 0.6472
# Epoch 43/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2717 - accuracy: 0.6185
# Epoch 43: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0043.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2716 - accuracy: 0.6185 - val_loss: 1.2075 - val_accuracy: 0.6472
# Epoch 44/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2716 - accuracy: 0.6186
# Epoch 44: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0044.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2715 - accuracy: 0.6187 - val_loss: 1.2075 - val_accuracy: 0.6486
# Epoch 45/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2712 - accuracy: 0.6187
# Epoch 45: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0045.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2712 - accuracy: 0.6186 - val_loss: 1.2076 - val_accuracy: 0.6474
# Epoch 46/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2711 - accuracy: 0.6187
# Epoch 46: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0046.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2711 - accuracy: 0.6187 - val_loss: 1.2078 - val_accuracy: 0.6470
# Epoch 47/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2709 - accuracy: 0.6186
# Epoch 47: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0047.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2710 - accuracy: 0.6185 - val_loss: 1.2068 - val_accuracy: 0.6480
# Epoch 48/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2708 - accuracy: 0.6191
# Epoch 48: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0048.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2707 - accuracy: 0.6191 - val_loss: 1.2067 - val_accuracy: 0.6486
# Epoch 49/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2703 - accuracy: 0.6190
# Epoch 49: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0049.ckpt
# 860/860 [==============================] - 25s 30ms/step - loss: 1.2704 - accuracy: 0.6189 - val_loss: 1.2074 - val_accuracy: 0.6474
# Epoch 50/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2699 - accuracy: 0.6190
# Epoch 50: saving model to checkpoint/20230206/z0_0.000500_seed_1/cp-0050.ckpt
# 860/860 [==============================] - 26s 30ms/step - loss: 1.2700 - accuracy: 0.6188 - val_loss: 1.2074 - val_accuracy: 0.6474
# WARNING:absl:Found untraced functions such as get_limited_eta, get_limited_theta, get_limited_eta, get_limited_theta, get_photo_mask while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_model/20230206/z0_0.000500_seed_1/assets
# INFO:tensorflow:Assets written to: trained_model/20230206/z0_0.000500_seed_1/assets

# %% [markdown]
# # 離散値

# %%
def create_model(**kwargs):
    shape = (100, 100)
    theta = -2.105 * np.pi / 180. / 2.
    eta = np.arctan(0.9785 * np.pi / 100. / 2.)
    z = kwargs["z"]
    tf.random.set_seed(kwargs["seed"])
    inputs = tf.keras.Input((28, 28))
    x = ImageResizing(shape)(inputs)
    x = ImageBinarization()(x)
    x = IntensityToElectricField(shape)(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=z, d=d, n=1.0, method='expand')(x)
    x = BinarizedMO(shape, theta=theta, eta=eta, beta=5.)(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=0.5e-3, d=d, n=2.0, method='expand')(x)
    x = BinarizedMO(shape, theta=theta, eta=eta, beta=5.)(x)
    x = AngularSpectrum(shape, wavelength=wavelength, z=0.5e-3, d=d, n=1.0, method='expand')(x)
    x = FaradayRotationByStokes(shape)(x)
    x = MNISTDetector(shape)(x)
    x = tf.keras.layers.Softmax()(x)
    model = tf.keras.Model(inputs, x)
    return model

# %%
def train(seed, z):
    model_name = "20230206/bi_z0_{:f}_seed_{:d}".format(z, seed)
    cholab_path = "/content/drive/MyDrive/D2NN/"
    checkpoint_path = "checkpoint/" + model_name + "/cp-{epoch:04d}.ckpt"
    checkpoint_dir = os.path.dirname(checkpoint_path)
    path = "trained_model/" + model_name

    model = create_model(seed=seed, z=z)
    model.summary()
    model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss=tf.keras.losses.sparse_categorical_crossentropy,  # category: sparse_categorical_crossentropy
                  metrics=["accuracy"]
                  )

    epochs = 50
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='loss',
        min_delta=0.0002,
        patience=2,
    )

    # チェックポイントコールバックを作る
    cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                     save_weights_only=True,
                                                     verbose=1)

    logdir = os.path.join(cholab_path + "logs", model_name)
    tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

    result = model.fit(x_train,
                       y_train,
                       batch_size=64,
                       epochs=epochs,
                       validation_data=(x_val, y_val),
                       callbacks=[cp_callback, tensorboard_callback]
                       )

    model.save(path)

    df = pd.DataFrame(result.history)
    df.to_csv(path + "/history.csv")

    with open(path + "/config.json", 'w') as f:
        json.dump(model.get_config(), f, indent=4)

# %%
train(1, 0.5e-3)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28)]          0
#
#  image_resizing_1 (ImageResi  (None, 100, 100)         0
#  zing)
#
#  image_binarization_1 (Image  (None, 100, 100)         0
#  Binarization)
#
#  intensity_to_electric_field  (None, 2, 100, 100)      0
#  _1 (IntensityToElectricFiel
#  d)
#
#  angular_spectrum_3 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  binarized_mo (BinarizedMO)  (None, 2, 100, 100)       10000
#
#  angular_spectrum_4 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  binarized_mo_1 (BinarizedMO  (None, 2, 100, 100)      10000
#  )
#
#  angular_spectrum_5 (Angular  (None, 2, 100, 100)      0
#  Spectrum)
#
#  faraday_rotation_by_stokes_  (None, 100, 100)         0
#  1 (FaradayRotationByStokes)
#
#  mnist_detector_1 (MNISTDete  (None, 10)               0
#  ctor)
#
#  softmax_1 (Softmax)         (None, 10)                0
#
# =================================================================
# Total params: 20,000
# Trainable params: 20,000
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.5500 - accuracy: 0.5218
# Epoch 1: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0001.ckpt
# 860/860 [==============================] - 27s 29ms/step - loss: 1.5500 - accuracy: 0.5218 - val_loss: 1.2954 - val_accuracy: 0.6184
# Epoch 2/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.3301 - accuracy: 0.5994
# Epoch 2: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0002.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.3299 - accuracy: 0.5995 - val_loss: 1.2411 - val_accuracy: 0.6298
# Epoch 3/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.3011 - accuracy: 0.6062
# Epoch 3: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0003.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.3011 - accuracy: 0.6063 - val_loss: 1.2235 - val_accuracy: 0.6364
# Epoch 4/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2888 - accuracy: 0.6117
# Epoch 4: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0004.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2887 - accuracy: 0.6117 - val_loss: 1.2167 - val_accuracy: 0.6456
# Epoch 5/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2843 - accuracy: 0.6127
# Epoch 5: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0005.ckpt
# 860/860 [==============================] - 25s 28ms/step - loss: 1.2842 - accuracy: 0.6127 - val_loss: 1.2164 - val_accuracy: 0.6426
# Epoch 6/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2798 - accuracy: 0.6148
# Epoch 6: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0006.ckpt
# 860/860 [==============================] - 24s 28ms/step - loss: 1.2799 - accuracy: 0.6148 - val_loss: 1.2153 - val_accuracy: 0.6428
# Epoch 7/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2774 - accuracy: 0.6156
# Epoch 7: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0007.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2773 - accuracy: 0.6157 - val_loss: 1.2129 - val_accuracy: 0.6458
# Epoch 8/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2765 - accuracy: 0.6156
# Epoch 8: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0008.ckpt
# 860/860 [==============================] - 24s 28ms/step - loss: 1.2765 - accuracy: 0.6156 - val_loss: 1.2124 - val_accuracy: 0.6448
# Epoch 9/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2754 - accuracy: 0.6161
# Epoch 9: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0009.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2754 - accuracy: 0.6161 - val_loss: 1.2106 - val_accuracy: 0.6440
# Epoch 10/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2741 - accuracy: 0.6173
# Epoch 10: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0010.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2741 - accuracy: 0.6173 - val_loss: 1.2146 - val_accuracy: 0.6486
# Epoch 11/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2734 - accuracy: 0.6169
# Epoch 11: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0011.ckpt
# 860/860 [==============================] - 33s 38ms/step - loss: 1.2733 - accuracy: 0.6170 - val_loss: 1.2075 - val_accuracy: 0.6476
# Epoch 12/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2734 - accuracy: 0.6157
# Epoch 12: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0012.ckpt
# 860/860 [==============================] - 24s 28ms/step - loss: 1.2734 - accuracy: 0.6157 - val_loss: 1.2076 - val_accuracy: 0.6434
# Epoch 13/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2719 - accuracy: 0.6179
# Epoch 13: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0013.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2721 - accuracy: 0.6178 - val_loss: 1.2091 - val_accuracy: 0.6454
# Epoch 14/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2723 - accuracy: 0.6177
# Epoch 14: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0014.ckpt
# 860/860 [==============================] - 25s 30ms/step - loss: 1.2723 - accuracy: 0.6178 - val_loss: 1.2071 - val_accuracy: 0.6454
# Epoch 15/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2718 - accuracy: 0.6172
# Epoch 15: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0015.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2718 - accuracy: 0.6171 - val_loss: 1.2089 - val_accuracy: 0.6462
# Epoch 16/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2727 - accuracy: 0.6177
# Epoch 16: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0016.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2727 - accuracy: 0.6177 - val_loss: 1.2069 - val_accuracy: 0.6436
# Epoch 17/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2721 - accuracy: 0.6178
# Epoch 17: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0017.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2720 - accuracy: 0.6178 - val_loss: 1.2058 - val_accuracy: 0.6454
# Epoch 18/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2715 - accuracy: 0.6176
# Epoch 18: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0018.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2715 - accuracy: 0.6176 - val_loss: 1.2051 - val_accuracy: 0.6484
# Epoch 19/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2716 - accuracy: 0.6180
# Epoch 19: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0019.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2715 - accuracy: 0.6180 - val_loss: 1.2053 - val_accuracy: 0.6490
# Epoch 20/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2699 - accuracy: 0.6190
# Epoch 20: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0020.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2699 - accuracy: 0.6190 - val_loss: 1.2084 - val_accuracy: 0.6444
# Epoch 21/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2708 - accuracy: 0.6162
# Epoch 21: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0021.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2707 - accuracy: 0.6163 - val_loss: 1.2072 - val_accuracy: 0.6476
# Epoch 22/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2696 - accuracy: 0.6193
# Epoch 22: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0022.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2696 - accuracy: 0.6194 - val_loss: 1.2080 - val_accuracy: 0.6436
# Epoch 23/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2701 - accuracy: 0.6191
# Epoch 23: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0023.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2701 - accuracy: 0.6191 - val_loss: 1.2048 - val_accuracy: 0.6460
# Epoch 24/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2696 - accuracy: 0.6178
# Epoch 24: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0024.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2696 - accuracy: 0.6178 - val_loss: 1.2059 - val_accuracy: 0.6464
# Epoch 25/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2700 - accuracy: 0.6184
# Epoch 25: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0025.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2701 - accuracy: 0.6183 - val_loss: 1.2040 - val_accuracy: 0.6454
# Epoch 26/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2693 - accuracy: 0.6205
# Epoch 26: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0026.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2692 - accuracy: 0.6205 - val_loss: 1.2032 - val_accuracy: 0.6470
# Epoch 27/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2697 - accuracy: 0.6194
# Epoch 27: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0027.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2697 - accuracy: 0.6193 - val_loss: 1.2052 - val_accuracy: 0.6488
# Epoch 28/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2692 - accuracy: 0.6189
# Epoch 28: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0028.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2691 - accuracy: 0.6190 - val_loss: 1.2033 - val_accuracy: 0.6486
# Epoch 29/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2697 - accuracy: 0.6189
# Epoch 29: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0029.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2697 - accuracy: 0.6189 - val_loss: 1.2047 - val_accuracy: 0.6468
# Epoch 30/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2700 - accuracy: 0.6187
# Epoch 30: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0030.ckpt
# 860/860 [==============================] - 25s 30ms/step - loss: 1.2701 - accuracy: 0.6187 - val_loss: 1.2035 - val_accuracy: 0.6484
# Epoch 31/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2691 - accuracy: 0.6190
# Epoch 31: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0031.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2692 - accuracy: 0.6190 - val_loss: 1.2035 - val_accuracy: 0.6470
# Epoch 32/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2689 - accuracy: 0.6197
# Epoch 32: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0032.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2691 - accuracy: 0.6197 - val_loss: 1.2033 - val_accuracy: 0.6468
# Epoch 33/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2691 - accuracy: 0.6197
# Epoch 33: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0033.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2693 - accuracy: 0.6197 - val_loss: 1.2062 - val_accuracy: 0.6458
# Epoch 34/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2692 - accuracy: 0.6177
# Epoch 34: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0034.ckpt
# 860/860 [==============================] - 30s 35ms/step - loss: 1.2692 - accuracy: 0.6177 - val_loss: 1.2010 - val_accuracy: 0.6554
# Epoch 35/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2691 - accuracy: 0.6196
# Epoch 35: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0035.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2691 - accuracy: 0.6195 - val_loss: 1.2011 - val_accuracy: 0.6494
# Epoch 36/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2689 - accuracy: 0.6183
# Epoch 36: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0036.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2688 - accuracy: 0.6183 - val_loss: 1.2056 - val_accuracy: 0.6486
# Epoch 37/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2688 - accuracy: 0.6197
# Epoch 37: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0037.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2687 - accuracy: 0.6198 - val_loss: 1.2044 - val_accuracy: 0.6492
# Epoch 38/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2687 - accuracy: 0.6194
# Epoch 38: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0038.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2687 - accuracy: 0.6194 - val_loss: 1.2088 - val_accuracy: 0.6484
# Epoch 39/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2699 - accuracy: 0.6189
# Epoch 39: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0039.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2698 - accuracy: 0.6189 - val_loss: 1.2051 - val_accuracy: 0.6480
# Epoch 40/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2687 - accuracy: 0.6188
# Epoch 40: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0040.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2687 - accuracy: 0.6188 - val_loss: 1.2038 - val_accuracy: 0.6480
# Epoch 41/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2685 - accuracy: 0.6186
# Epoch 41: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0041.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2685 - accuracy: 0.6186 - val_loss: 1.2034 - val_accuracy: 0.6514
# Epoch 42/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2691 - accuracy: 0.6203
# Epoch 42: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0042.ckpt
# 860/860 [==============================] - 32s 37ms/step - loss: 1.2690 - accuracy: 0.6204 - val_loss: 1.2031 - val_accuracy: 0.6512
# Epoch 43/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2684 - accuracy: 0.6187
# Epoch 43: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0043.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2684 - accuracy: 0.6187 - val_loss: 1.2037 - val_accuracy: 0.6484
# Epoch 44/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2686 - accuracy: 0.6178
# Epoch 44: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0044.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2685 - accuracy: 0.6178 - val_loss: 1.2025 - val_accuracy: 0.6472
# Epoch 45/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2687 - accuracy: 0.6198
# Epoch 45: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0045.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2687 - accuracy: 0.6197 - val_loss: 1.2043 - val_accuracy: 0.6496
# Epoch 46/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2683 - accuracy: 0.6191
# Epoch 46: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0046.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2682 - accuracy: 0.6191 - val_loss: 1.2028 - val_accuracy: 0.6452
# Epoch 47/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2684 - accuracy: 0.6178
# Epoch 47: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0047.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2685 - accuracy: 0.6177 - val_loss: 1.2026 - val_accuracy: 0.6468
# Epoch 48/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2688 - accuracy: 0.6187
# Epoch 48: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0048.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2687 - accuracy: 0.6187 - val_loss: 1.2025 - val_accuracy: 0.6480
# Epoch 49/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2686 - accuracy: 0.6192
# Epoch 49: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0049.ckpt
# 860/860 [==============================] - 25s 29ms/step - loss: 1.2687 - accuracy: 0.6192 - val_loss: 1.2041 - val_accuracy: 0.6464
# Epoch 50/50
# 859/860 [============================>.] - ETA: 0s - loss: 1.2686 - accuracy: 0.6196
# Epoch 50: saving model to checkpoint/20230206/bi_z0_0.000500_seed_1/cp-0050.ckpt
# 860/860 [==============================] - 29s 34ms/step - loss: 1.2687 - accuracy: 0.6195 - val_loss: 1.2024 - val_accuracy: 0.6480
# WARNING:absl:Found untraced functions such as get_b_kernel, get_limited_complex_faraday, get_limited_eta, get_limited_theta, get_b_kernel while saving (showing 5 of 9). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_model/20230206/bi_z0_0.000500_seed_1/assets
# INFO:tensorflow:Assets written to: trained_model/20230206/bi_z0_0.000500_seed_1/assets
