# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

plt.rcParams["font.size"]=18

# %%
x = np.linspace(-5, 5, 100)
y = tf.tanh(x)

plt.plot(x, y)
plt.yticks([-1, 0, 1], ["-a", "0", "a"])
plt.xlabel(r'$\phi$')
plt.ylabel(r'$\phi_{limited}$')
# Out:
# Text(0, 0.5, '$\\phi_{limited}$')
